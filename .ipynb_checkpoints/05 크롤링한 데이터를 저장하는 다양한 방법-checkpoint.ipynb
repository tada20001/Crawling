# %% [markdown]
# 1. 파일 포맷으로는 json, json lines, pickle에 대해서 살펴보며, Pandas를 활용한 CSV/XLSX 저장에 대해서도 살펴본다.
#
# 2. 추가로 RDB로의 저장방법을 살펴보는데, dataset 라이브러리를 활용하여 sqlite 기준으로 코드를 보여주나,
#
# 3. MySQL/PostgreSQL 등의 서버로 세팅이 되어있다면 계정정보 변경만으로 손쉽게 insert를 할 수 있다.

# %%
import requests
from bs4 import BeautifulSoup

headers = {
    'User-Agent': ('Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_3) '
                   'AppleWebKit/537.36 (KHTML, like Gecko) Chrome/72.0.3626.121 Safari/537.36'),
}
res = requests.get("http://www.melon.com/chart/index.htm", headers=headers)
html = res.text
soup = BeautifulSoup(html, 'html.parser')
tr_tag_list = soup.select('.d_song_list tbody tr')

song_list = []

for rank, tr_tag in enumerate(tr_tag_list, 1):
    song_tag = tr_tag.select_one('a[href*=playSong]')
    album_tag = tr_tag.select_one('.wrap_song_info a[href*=goAlbumDetail]')
    artist_tag = tr_tag.select_one('a[href*=goArtistDetail]')

    song = {
        'title': song_tag.text,
        'album': album_tag.text,
        'artist': artist_tag.text,
        'rank': rank,
    }
    song_list.append(song)

song_list
# Out:
# [{'title': '어떻게 이별까지 사랑하겠어, 널 사랑하는 거지',
#   'album': '항해',
#   'artist': 'AKMU (악동뮤지션)',
#   'rank': 1},
#  {'title': '새 사랑', 'album': '새 사랑', 'artist': '송하예', 'rank': 2},
#  {'title': '흔들리는 꽃들 속에서 네 샴푸향이 느껴진거야',
#   'album': '멜로가 체질 OST Part 3',
#   'artist': '장범준',
#   'rank': 3},
#  {'title': '떨어지는 낙엽까지도', 'album': '만추', 'artist': '헤이즈 (Heize)', 'rank': 4},
#  {'title': '있어줘요', 'album': '있어줘요', 'artist': '장덕철', 'rank': 5},
#  {'title': '조금 취했어 (Prod. 2soo)',
#   'album': '조금 취했어',
#   'artist': '임재현',
#   'rank': 6},
#  {'title': '허전해', 'album': "정규 2집 '마음, 하나'", 'artist': '폴킴', 'rank': 7},
#  {'title': '사랑이란 멜로는 없어', 'album': '사랑이란 멜로는 없어', 'artist': '전상근', 'rank': 8},
#  {'title': '워커홀릭', 'album': 'Two Five', 'artist': '볼빨간사춘기', 'rank': 9},
#  {'title': '안녕', 'album': '호텔 델루나 OST Part.10', 'artist': '폴킴', 'rank': 10},
#  {'title': '오늘도 빛나는 너에게 (To You My Light) (Feat.이라온)',
#   'album': 'Red Moon : To You My Light',
#   'artist': '마크툽 (MAKTUB)',
#   'rank': 11},
#  {'title': '시든 꽃에 물을 주듯',
#   'album': '시든 꽃에 물을 주듯',
#   'artist': 'HYNN(박혜원)',
#   'rank': 12},
#  {'title': '가을밤 떠난 너', 'album': 'Rewind', 'artist': '케이시 (Kassy)', 'rank': 13},
#  {'title': 'Feel Special',
#   'album': 'Feel Special',
#   'artist': 'TWICE (트와이스)',
#   'rank': 14},
#  {'title': '니 소식', 'album': '니 소식', 'artist': '송하예', 'rank': 15},
#  {'title': '우리 어떻게 할까요',
#   'album': '사랑하는 그대에게 - The 2nd Mini Album',
#   'artist': '첸 (CHEN)',
#   'rank': 16},
#  {'title': '기억해줘요 내 모든 날과 그때를',
#   'album': '호텔 델루나 OST Part.7',
#   'artist': '거미',
#   'rank': 17},
#  {'title': '포장마차', 'album': '포장마차', 'artist': '황인욱', 'rank': 18},
#  {'title': '만추 (Feat. Crush)',
#   'album': '만추',
#   'artist': '헤이즈 (Heize)',
#   'rank': 19},
#  {'title': '가끔 이러다', 'album': '가끔 이러다', 'artist': '펀치 (Punch)', 'rank': 20},
#  {'title': '헤어지자 (Prod. 정키)',
#   'album': 'soar',
#   'artist': '휘인 (Whee In)',
#   'rank': 21},
#  {'title': '2002',
#   'album': 'Speak Your Mind (Deluxe)',
#   'artist': 'Anne-Marie',
#   'rank': 22},
#  {'title': 'Señorita',
#   'album': 'Señorita',
#   'artist': 'Shawn Mendes',
#   'rank': 23},
#  {'title': '천둥벌거숭이 (Feat. Jvcki Wai, 염따)',
#   'album': 'THINKING Part.1',
#   'artist': '지코 (ZICO)',
#   'rank': 24},
#  {'title': '사랑에 연습이 있었다면 (Prod. 2soo)',
#   'album': '사랑에 연습이 있었다면',
#   'artist': '임재현',
#   'rank': 25},
#  {'title': '그대라는 시',
#   'album': '호텔 델루나 OST Part.3',
#   'artist': '태연 (TAEYEON)',
#   'rank': 26},
#  {'title': '술이 문제야', 'album': '술이 문제야', 'artist': '장혜진', 'rank': 27},
#  {'title': '사랑이 식었다고 말해도 돼',
#   'album': '사랑이 식었다고 말해도 돼',
#   'artist': '먼데이 키즈 (Monday Kiz)',
#   'rank': 28},
#  {'title': '작은 것들을 위한 시 (Boy With Luv) feat. Halsey',
#   'album': 'MAP OF THE SOUL : PERSONA',
#   'artist': '방탄소년단',
#   'rank': 29},
#  {'title': '모든 날, 모든 순간 (Every day, Every Moment)',
#   'album': '`키스 먼저 할까요?` OST Part.3',
#   'artist': '폴킴',
#   'rank': 30},
#  {'title': 'bad guy',
#   'album': 'WHEN WE ALL FALL ASLEEP, WHERE DO WE GO?',
#   'artist': 'Billie Eilish',
#   'rank': 31},
#  {'title': '호랑이소굴 (Feat. Jvcki Wai)',
#   'album': '호랑이소굴',
#   'artist': '기리보이',
#   'rank': 32},
#  {'title': '사람',
#   'album': 'THINKING Part.1',
#   'artist': '지코 (ZICO)',
#   'rank': 33},
#  {'title': '이별행동', 'album': '이별행동', 'artist': '이우', 'rank': 34},
#  {'title': '다시 만날까 봐', 'album': '다시 만날까 봐', 'artist': 'V.O.S', 'rank': 35},
#  {'title': 'BAND', 'album': 'BAND', 'artist': '창모 (CHANGMO)', 'rank': 36},
#  {'title': '헤어져줘서 고마워', 'album': '헤어져줘서 고마워', 'artist': '벤', 'rank': 37},
#  {'title': '복숭아', 'album': '스무 살의 봄', 'artist': '아이유', 'rank': 38},
#  {'title': '나의 어깨에 기대어요',
#   'album': '호텔 델루나 OST Part.2',
#   'artist': '10cm',
#   'rank': 39},
#  {'title': 'Done For Me',
#   'album': '호텔 델루나 OST Part.12',
#   'artist': '펀치 (Punch)',
#   'rank': 40},
#  {'title': '내 목소리 들리니',
#   'album': '호텔 델루나 OST Part.9',
#   'artist': '벤',
#   'rank': 41},
#  {'title': '꽃처럼 예쁜 그대',
#   'album': '동백꽃 필 무렵 (KBS2 수목드라마) OST - Part.4',
#   'artist': '임한별',
#   'rank': 42},
#  {'title': '달', 'album': '항해', 'artist': 'AKMU (악동뮤지션)', 'rank': 43},
#  {'title': '벗', 'album': '벗', 'artist': '닐로(Nilo)', 'rank': 44},
#  {'title': 'Speechless (Full)',
#   'album': 'Aladdin (Original Motion Picture Soundtrack)',
#   'artist': 'Naomi Scott',
#   'rank': 45},
#  {'title': '사월이 지나면 우리 헤어져요 (Beautiful goodbye)',
#   'album': '사월, 그리고 꽃 - The 1st Mini Album',
#   'artist': '첸 (CHEN)',
#   'rank': 46},
#  {'title': '널 안지 않을 수 있어야지',
#   'album': '사랑하는 그대에게 - The 2nd Mini Album',
#   'artist': '첸 (CHEN)',
#   'rank': 47},
#  {'title': '너를 만나', 'album': '너를 만나', 'artist': '폴킴', 'rank': 48},
#  {'title': '사계 (Four Seasons)',
#   'album': '사계 (Four Seasons)',
#   'artist': '태연 (TAEYEON)',
#   'rank': 49},
#  {'title': '내 맘을 볼 수 있나요',
#   'album': '호텔 델루나 OST Part.5',
#   'artist': '헤이즈 (Heize)',
#   'rank': 50},
#  {'title': '날라리 (LALALAY)',
#   'album': '날라리 (LALALAY)',
#   'artist': '선미',
#   'rank': 51},
#  {'title': '우리 시작해도 괜찮을까요',
#   'album': '우리 시작해도 괜찮을까요',
#   'artist': '정준일',
#   'rank': 52},
#  {'title': '헤어질 자신 있니 (Narr. SBS 박선영 아나운서)',
#   'album': '헤어질 자신 있니',
#   'artist': '앤씨아',
#   'rank': 53},
#  {'title': '솔직하게 말해서 나', 'album': '솔직하게 말해서 나', 'artist': '김나영', 'rank': 54},
#  {'title': '너에게 못했던 내 마지막 말은',
#   'album': '너에게 못했던 내 마지막 말은',
#   'artist': '다비치',
#   'rank': 55},
#  {'title': '그때가 좋았어', 'album': '그때가 좋았어', 'artist': '케이시 (Kassy)', 'rank': 56},
#  {'title': 'Paris In The Rain',
#   'album': 'I met you when I was 18. (the playlist)',
#   'artist': 'Lauv',
#   'rank': 57},
#  {'title': '노래방에서', 'album': '장범준 3집', 'artist': '장범준', 'rank': 58},
#  {'title': '내 안부', 'album': '내 안부', 'artist': '이우', 'rank': 59},
#  {'title': '나빠(NAPPA)', 'album': '나빠(NAPPA)', 'artist': 'Crush', 'rank': 60},
#  {'title': 'ICY', 'album': 'IT`z ICY', 'artist': 'ITZY (있지)', 'rank': 61},
#  {'title': '전화를 할까봐', 'album': '전화를 할까봐', 'artist': '오반', 'rank': 62},
#  {'title': '일기', 'album': '만추', 'artist': '헤이즈 (Heize)', 'rank': 63},
#  {'title': 'FANCY',
#   'album': 'FANCY YOU',
#   'artist': 'TWICE (트와이스)',
#   'rank': 64},
#  {'title': 'FREEDOM', 'album': '항해', 'artist': 'AKMU (악동뮤지션)', 'rank': 65},
#  {'title': 'FLASH',
#   'album': '비상 : QUANTUM LEAP',
#   'artist': 'X1 (엑스원)',
#   'rank': 66},
#  {'title': '인사', 'album': '인사', 'artist': '멜로망스', 'rank': 67},
#  {'title': '가을속에서',
#   'album': '화실(化-室:atelier)',
#   'artist': '화사(Hwa Sa)',
#   'rank': 68},
#  {'title': '주저하는 연인들을 위해', 'album': '전설', 'artist': '잔나비', 'rank': 69},
#  {'title': '꿈속에 너 (Feat. 전상근)',
#   'album': '두 번째 이야기',
#   'artist': '에이치코드 (H:CODE)',
#   'rank': 70},
#  {'title': 'Snapping', 'album': 'Flourishing', 'artist': '청하', 'rank': 71},
#  {'title': '봄날',
#   'album': 'YOU NEVER WALK ALONE',
#   'artist': '방탄소년단',
#   'rank': 72},
#  {'title': '그대에게',
#   'album': '사랑하는 그대에게 - The 2nd Mini Album',
#   'artist': '첸 (CHEN)',
#   'rank': 73},
#  {'title': '괜찮아도 괜찮아 (That`s okay)',
#   'album': '괜찮아도 괜찮아 (That`s okay) - SM STATION',
#   'artist': '디오 (D.O.)',
#   'rank': 74},
#  {'title': '가라사대',
#   'album': 'The Movie Star',
#   'artist': 'BewhY (비와이)',
#   'rank': 75},
#  {'title': 'Believer',
#   'album': 'Evolve',
#   'artist': 'Imagine Dragons',
#   'rank': 76},
#  {'title': '물 만난 물고기', 'album': '항해', 'artist': 'AKMU (악동뮤지션)', 'rank': 77},
#  {'title': '고운 그대는 시들지 않으리',
#   'album': '사랑하는 그대에게 - The 2nd Mini Album',
#   'artist': '첸 (CHEN)',
#   'rank': 78},
#  {'title': '담아 (Feat. 염따, pH-1) (Prod. BOYCOLD)',
#   'album': '쇼미더머니 8 Episode 1',
#   'artist': '스윙스',
#   'rank': 79},
#  {'title': 'Another Day',
#   'album': '호텔 델루나 OST Part.1',
#   'artist': '먼데이 키즈 (Monday Kiz)',
#   'rank': 80},
#  {'title': '그댄 모르죠',
#   'album': '사랑하는 그대에게 - The 2nd Mini Album',
#   'artist': '첸 (CHEN)',
#   'rank': 81},
#  {'title': 'IDOL',
#   'album': 'LOVE YOURSELF 結 `Answer`',
#   'artist': '방탄소년단',
#   'rank': 82},
#  {'title': '사랑 둘', 'album': '사랑 둘', 'artist': '김필', 'rank': 83},
#  {'title': '밤 끝없는 밤', 'album': '항해', 'artist': 'AKMU (악동뮤지션)', 'rank': 84},
#  {'title': '아퍼 (Feat. Kid Milli, Lil tachi, 김승민, NO:EL, C JAMM)',
#   'album': '100년제전문대학',
#   'artist': '기리보이',
#   'rank': 85},
#  {'title': '굿밤 (GOOD BAM)',
#   'album': '야호(夜好)',
#   'artist': '엔플라잉 (N.Flying)',
#   'rank': 86},
#  {'title': '나만 아픈 일', 'album': '나만 아픈 일', 'artist': '이해리 (다비치)', 'rank': 87},
#  {'title': '비', 'album': '비', 'artist': '폴킴', 'rank': 88},
#  {'title': '뱃노래', 'album': '항해', 'artist': 'AKMU (악동뮤지션)', 'rank': 89},
#  {'title': 'DAUM (Feat. Colde)',
#   'album': '만추',
#   'artist': '헤이즈 (Heize)',
#   'rank': 90},
#  {'title': 'We don`t talk together (Feat. 기리보이) (Prod. SUGA)',
#   'album': 'We don`t talk together',
#   'artist': '헤이즈 (Heize)',
#   'rank': 91},
#  {'title': '달라달라',
#   'album': 'IT`z Different',
#   'artist': 'ITZY (있지)',
#   'rank': 92},
#  {'title': '잘 자요',
#   'album': '사랑하는 그대에게 - The 2nd Mini Album',
#   'artist': '첸 (CHEN)',
#   'rank': 93},
#  {'title': 'Goodbye', 'album': 'Goodbye', 'artist': '박효신', 'rank': 94},
#  {'title': '음파음파 (Umpah Umpah)',
#   'album': '‘The ReVe Festival’ Day 2',
#   'artist': 'Red Velvet (레드벨벳)',
#   'rank': 95},
#  {'title': '사계 (하루살이)', 'album': 'Circular', 'artist': '엠씨더맥스', 'rank': 96},
#  {'title': 'Love Shot',
#   'album': 'LOVE SHOT - The 5th Album Repackage',
#   'artist': 'EXO',
#   'rank': 97},
#  {'title': 'XX', 'album': 'Two Five', 'artist': '볼빨간사춘기', 'rank': 98},
#  {'title': 'Way Back Home',
#   'album': 'Take',
#   'artist': '숀 (SHAUN)',
#   'rank': 99},
#  {'title': '우리 만난다면', 'album': '낮과 밤', 'artist': '스무살', 'rank': 100}]

# %% [markdown]
# ## 데이터를 저장하는 다양한 방법
# * 파일 : json 포맷, json lines 포맷, pickle 포맷 등
# * CSV 포맷 엑셀
# * 데이터베이스

# %% [markdown]
# ## JSON 포맷
# * XML과 함께 주요 데이터 포맷
# * 언어 독립적이며 Numbers/String/Boolean/Array/Object/null 타입 지원
# * 웹에서 Ajax 통신 시에 주요 활용
# * 데이터 객체를 아무리 커도 한번에 변환 -> 데이터 append 시에도 전체 변환이 필요

# %%
import json

# song_list 객체를 한번에 JSON 포맷 문자열로 변환
# song_list의 경우 json이 지원하는 타입만 입력해야 함
# ensure_ascii=False : string 원래 타입으로 변환, 지정하지 않으면 bytes 형태로 변환
json_string = json.dumps(song_list, indent=4, ensure_ascii=False) # indent : 띄어쓰기


# 저장할때 ecoding='utf8'을 지정해 두는 것이 좋음
with open("melon_chart.json", "wt", encoding="utf8") as f:  # wt : write text mode
    f.write(json_string)

# %%
# JSON 파일 읽어서 객체로 변환
with open("melon_chart.json", "rt", encoding="utf8") as f:
    json_string = f.read()
    song_list = json.loads(json_string)

# %%
from pprint import pprint
pprint(song_list)
# Out:
# [{'album': '항해',
#   'artist': 'AKMU (악동뮤지션)',
#   'rank': 1,
#   'title': '어떻게 이별까지 사랑하겠어, 널 사랑하는 거지'},
#  {'album': '새 사랑', 'artist': '송하예', 'rank': 2, 'title': '새 사랑'},
#  {'album': '멜로가 체질 OST Part 3',
#   'artist': '장범준',
#   'rank': 3,
#   'title': '흔들리는 꽃들 속에서 네 샴푸향이 느껴진거야'},
#  {'album': '만추', 'artist': '헤이즈 (Heize)', 'rank': 4, 'title': '떨어지는 낙엽까지도'},
#  {'album': '있어줘요', 'artist': '장덕철', 'rank': 5, 'title': '있어줘요'},
#  {'album': '조금 취했어',
#   'artist': '임재현',
#   'rank': 6,
#   'title': '조금 취했어 (Prod. 2soo)'},
#  {'album': "정규 2집 '마음, 하나'", 'artist': '폴킴', 'rank': 7, 'title': '허전해'},
#  {'album': '사랑이란 멜로는 없어', 'artist': '전상근', 'rank': 8, 'title': '사랑이란 멜로는 없어'},
#  {'album': 'Two Five', 'artist': '볼빨간사춘기', 'rank': 9, 'title': '워커홀릭'},
#  {'album': '호텔 델루나 OST Part.10', 'artist': '폴킴', 'rank': 10, 'title': '안녕'},
#  {'album': 'Red Moon : To You My Light',
#   'artist': '마크툽 (MAKTUB)',
#   'rank': 11,
#   'title': '오늘도 빛나는 너에게 (To You My Light) (Feat.이라온)'},
#  {'album': '시든 꽃에 물을 주듯',
#   'artist': 'HYNN(박혜원)',
#   'rank': 12,
#   'title': '시든 꽃에 물을 주듯'},
#  {'album': 'Rewind', 'artist': '케이시 (Kassy)', 'rank': 13, 'title': '가을밤 떠난 너'},
#  {'album': 'Feel Special',
#   'artist': 'TWICE (트와이스)',
#   'rank': 14,
#   'title': 'Feel Special'},
#  {'album': '니 소식', 'artist': '송하예', 'rank': 15, 'title': '니 소식'},
#  {'album': '사랑하는 그대에게 - The 2nd Mini Album',
#   'artist': '첸 (CHEN)',
#   'rank': 16,
#   'title': '우리 어떻게 할까요'},
#  {'album': '호텔 델루나 OST Part.7',
#   'artist': '거미',
#   'rank': 17,
#   'title': '기억해줘요 내 모든 날과 그때를'},
#  {'album': '포장마차', 'artist': '황인욱', 'rank': 18, 'title': '포장마차'},
#  {'album': '만추',
#   'artist': '헤이즈 (Heize)',
#   'rank': 19,
#   'title': '만추 (Feat. Crush)'},
#  {'album': '가끔 이러다', 'artist': '펀치 (Punch)', 'rank': 20, 'title': '가끔 이러다'},
#  {'album': 'soar',
#   'artist': '휘인 (Whee In)',
#   'rank': 21,
#   'title': '헤어지자 (Prod. 정키)'},
#  {'album': 'Speak Your Mind (Deluxe)',
#   'artist': 'Anne-Marie',
#   'rank': 22,
#   'title': '2002'},
#  {'album': 'Señorita',
#   'artist': 'Shawn Mendes',
#   'rank': 23,
#   'title': 'Señorita'},
#  {'album': 'THINKING Part.1',
#   'artist': '지코 (ZICO)',
#   'rank': 24,
#   'title': '천둥벌거숭이 (Feat. Jvcki Wai, 염따)'},
#  {'album': '사랑에 연습이 있었다면',
#   'artist': '임재현',
#   'rank': 25,
#   'title': '사랑에 연습이 있었다면 (Prod. 2soo)'},
#  {'album': '호텔 델루나 OST Part.3',
#   'artist': '태연 (TAEYEON)',
#   'rank': 26,
#   'title': '그대라는 시'},
#  {'album': '술이 문제야', 'artist': '장혜진', 'rank': 27, 'title': '술이 문제야'},
#  {'album': '사랑이 식었다고 말해도 돼',
#   'artist': '먼데이 키즈 (Monday Kiz)',
#   'rank': 28,
#   'title': '사랑이 식었다고 말해도 돼'},
#  {'album': 'MAP OF THE SOUL : PERSONA',
#   'artist': '방탄소년단',
#   'rank': 29,
#   'title': '작은 것들을 위한 시 (Boy With Luv) feat. Halsey'},
#  {'album': '`키스 먼저 할까요?` OST Part.3',
#   'artist': '폴킴',
#   'rank': 30,
#   'title': '모든 날, 모든 순간 (Every day, Every Moment)'},
#  {'album': 'WHEN WE ALL FALL ASLEEP, WHERE DO WE GO?',
#   'artist': 'Billie Eilish',
#   'rank': 31,
#   'title': 'bad guy'},
#  {'album': '호랑이소굴',
#   'artist': '기리보이',
#   'rank': 32,
#   'title': '호랑이소굴 (Feat. Jvcki Wai)'},
#  {'album': 'THINKING Part.1', 'artist': '지코 (ZICO)', 'rank': 33, 'title': '사람'},
#  {'album': '이별행동', 'artist': '이우', 'rank': 34, 'title': '이별행동'},
#  {'album': '다시 만날까 봐', 'artist': 'V.O.S', 'rank': 35, 'title': '다시 만날까 봐'},
#  {'album': 'BAND', 'artist': '창모 (CHANGMO)', 'rank': 36, 'title': 'BAND'},
#  {'album': '헤어져줘서 고마워', 'artist': '벤', 'rank': 37, 'title': '헤어져줘서 고마워'},
#  {'album': '스무 살의 봄', 'artist': '아이유', 'rank': 38, 'title': '복숭아'},
#  {'album': '호텔 델루나 OST Part.2',
#   'artist': '10cm',
#   'rank': 39,
#   'title': '나의 어깨에 기대어요'},
#  {'album': '호텔 델루나 OST Part.12',
#   'artist': '펀치 (Punch)',
#   'rank': 40,
#   'title': 'Done For Me'},
#  {'album': '호텔 델루나 OST Part.9',
#   'artist': '벤',
#   'rank': 41,
#   'title': '내 목소리 들리니'},
#  {'album': '동백꽃 필 무렵 (KBS2 수목드라마) OST - Part.4',
#   'artist': '임한별',
#   'rank': 42,
#   'title': '꽃처럼 예쁜 그대'},
#  {'album': '항해', 'artist': 'AKMU (악동뮤지션)', 'rank': 43, 'title': '달'},
#  {'album': '벗', 'artist': '닐로(Nilo)', 'rank': 44, 'title': '벗'},
#  {'album': 'Aladdin (Original Motion Picture Soundtrack)',
#   'artist': 'Naomi Scott',
#   'rank': 45,
#   'title': 'Speechless (Full)'},
#  {'album': '사월, 그리고 꽃 - The 1st Mini Album',
#   'artist': '첸 (CHEN)',
#   'rank': 46,
#   'title': '사월이 지나면 우리 헤어져요 (Beautiful goodbye)'},
#  {'album': '사랑하는 그대에게 - The 2nd Mini Album',
#   'artist': '첸 (CHEN)',
#   'rank': 47,
#   'title': '널 안지 않을 수 있어야지'},
#  {'album': '너를 만나', 'artist': '폴킴', 'rank': 48, 'title': '너를 만나'},
#  {'album': '사계 (Four Seasons)',
#   'artist': '태연 (TAEYEON)',
#   'rank': 49,
#   'title': '사계 (Four Seasons)'},
#  {'album': '호텔 델루나 OST Part.5',
#   'artist': '헤이즈 (Heize)',
#   'rank': 50,
#   'title': '내 맘을 볼 수 있나요'},
#  {'album': '날라리 (LALALAY)',
#   'artist': '선미',
#   'rank': 51,
#   'title': '날라리 (LALALAY)'},
#  {'album': '우리 시작해도 괜찮을까요',
#   'artist': '정준일',
#   'rank': 52,
#   'title': '우리 시작해도 괜찮을까요'},
#  {'album': '헤어질 자신 있니',
#   'artist': '앤씨아',
#   'rank': 53,
#   'title': '헤어질 자신 있니 (Narr. SBS 박선영 아나운서)'},
#  {'album': '솔직하게 말해서 나', 'artist': '김나영', 'rank': 54, 'title': '솔직하게 말해서 나'},
#  {'album': '너에게 못했던 내 마지막 말은',
#   'artist': '다비치',
#   'rank': 55,
#   'title': '너에게 못했던 내 마지막 말은'},
#  {'album': '그때가 좋았어', 'artist': '케이시 (Kassy)', 'rank': 56, 'title': '그때가 좋았어'},
#  {'album': 'I met you when I was 18. (the playlist)',
#   'artist': 'Lauv',
#   'rank': 57,
#   'title': 'Paris In The Rain'},
#  {'album': '장범준 3집', 'artist': '장범준', 'rank': 58, 'title': '노래방에서'},
#  {'album': '내 안부', 'artist': '이우', 'rank': 59, 'title': '내 안부'},
#  {'album': '나빠(NAPPA)', 'artist': 'Crush', 'rank': 60, 'title': '나빠(NAPPA)'},
#  {'album': 'IT`z ICY', 'artist': 'ITZY (있지)', 'rank': 61, 'title': 'ICY'},
#  {'album': '전화를 할까봐', 'artist': '오반', 'rank': 62, 'title': '전화를 할까봐'},
#  {'album': '만추', 'artist': '헤이즈 (Heize)', 'rank': 63, 'title': '일기'},
#  {'album': 'FANCY YOU', 'artist': 'TWICE (트와이스)', 'rank': 64, 'title': 'FANCY'},
#  {'album': '항해', 'artist': 'AKMU (악동뮤지션)', 'rank': 65, 'title': 'FREEDOM'},
#  {'album': '비상 : QUANTUM LEAP',
#   'artist': 'X1 (엑스원)',
#   'rank': 66,
#   'title': 'FLASH'},
#  {'album': '인사', 'artist': '멜로망스', 'rank': 67, 'title': '인사'},
#  {'album': '화실(化-室:atelier)',
#   'artist': '화사(Hwa Sa)',
#   'rank': 68,
#   'title': '가을속에서'},
#  {'album': '전설', 'artist': '잔나비', 'rank': 69, 'title': '주저하는 연인들을 위해'},
#  {'album': '두 번째 이야기',
#   'artist': '에이치코드 (H:CODE)',
#   'rank': 70,
#   'title': '꿈속에 너 (Feat. 전상근)'},
#  {'album': 'Flourishing', 'artist': '청하', 'rank': 71, 'title': 'Snapping'},
#  {'album': 'YOU NEVER WALK ALONE',
#   'artist': '방탄소년단',
#   'rank': 72,
#   'title': '봄날'},
#  {'album': '사랑하는 그대에게 - The 2nd Mini Album',
#   'artist': '첸 (CHEN)',
#   'rank': 73,
#   'title': '그대에게'},
#  {'album': '괜찮아도 괜찮아 (That`s okay) - SM STATION',
#   'artist': '디오 (D.O.)',
#   'rank': 74,
#   'title': '괜찮아도 괜찮아 (That`s okay)'},
#  {'album': 'The Movie Star',
#   'artist': 'BewhY (비와이)',
#   'rank': 75,
#   'title': '가라사대'},
#  {'album': 'Evolve',
#   'artist': 'Imagine Dragons',
#   'rank': 76,
#   'title': 'Believer'},
#  {'album': '항해', 'artist': 'AKMU (악동뮤지션)', 'rank': 77, 'title': '물 만난 물고기'},
#  {'album': '사랑하는 그대에게 - The 2nd Mini Album',
#   'artist': '첸 (CHEN)',
#   'rank': 78,
#   'title': '고운 그대는 시들지 않으리'},
#  {'album': '쇼미더머니 8 Episode 1',
#   'artist': '스윙스',
#   'rank': 79,
#   'title': '담아 (Feat. 염따, pH-1) (Prod. BOYCOLD)'},
#  {'album': '호텔 델루나 OST Part.1',
#   'artist': '먼데이 키즈 (Monday Kiz)',
#   'rank': 80,
#   'title': 'Another Day'},
#  {'album': '사랑하는 그대에게 - The 2nd Mini Album',
#   'artist': '첸 (CHEN)',
#   'rank': 81,
#   'title': '그댄 모르죠'},
#  {'album': 'LOVE YOURSELF 結 `Answer`',
#   'artist': '방탄소년단',
#   'rank': 82,
#   'title': 'IDOL'},
#  {'album': '사랑 둘', 'artist': '김필', 'rank': 83, 'title': '사랑 둘'},
#  {'album': '항해', 'artist': 'AKMU (악동뮤지션)', 'rank': 84, 'title': '밤 끝없는 밤'},
#  {'album': '100년제전문대학',
#   'artist': '기리보이',
#   'rank': 85,
#   'title': '아퍼 (Feat. Kid Milli, Lil tachi, 김승민, NO:EL, C JAMM)'},
#  {'album': '야호(夜好)',
#   'artist': '엔플라잉 (N.Flying)',
#   'rank': 86,
#   'title': '굿밤 (GOOD BAM)'},
#  {'album': '나만 아픈 일', 'artist': '이해리 (다비치)', 'rank': 87, 'title': '나만 아픈 일'},
#  {'album': '비', 'artist': '폴킴', 'rank': 88, 'title': '비'},
#  {'album': '항해', 'artist': 'AKMU (악동뮤지션)', 'rank': 89, 'title': '뱃노래'},
#  {'album': '만추',
#   'artist': '헤이즈 (Heize)',
#   'rank': 90,
#   'title': 'DAUM (Feat. Colde)'},
#  {'album': 'We don`t talk together',
#   'artist': '헤이즈 (Heize)',
#   'rank': 91,
#   'title': 'We don`t talk together (Feat. 기리보이) (Prod. SUGA)'},
#  {'album': 'IT`z Different',
#   'artist': 'ITZY (있지)',
#   'rank': 92,
#   'title': '달라달라'},
#  {'album': '사랑하는 그대에게 - The 2nd Mini Album',
#   'artist': '첸 (CHEN)',
#   'rank': 93,
#   'title': '잘 자요'},
#  {'album': 'Goodbye', 'artist': '박효신', 'rank': 94, 'title': 'Goodbye'},
#  {'album': '‘The ReVe Festival’ Day 2',
#   'artist': 'Red Velvet (레드벨벳)',
#   'rank': 95,
#   'title': '음파음파 (Umpah Umpah)'},
#  {'album': 'Circular', 'artist': '엠씨더맥스', 'rank': 96, 'title': '사계 (하루살이)'},
#  {'album': 'LOVE SHOT - The 5th Album Repackage',
#   'artist': 'EXO',
#   'rank': 97,
#   'title': 'Love Shot'},
#  {'album': 'Two Five', 'artist': '볼빨간사춘기', 'rank': 98, 'title': 'XX'},
#  {'album': 'Take', 'artist': '숀 (SHAUN)', 'rank': 99, 'title': 'Way Back Home'},
#  {'album': '낮과 밤', 'artist': '스무살', 'rank': 100, 'title': '우리 만난다면'}]

# %%
type(json_string), type(song_list)
# Out:
# (str, list)

# %%
print(json_string)  # 하나의 거대한 문자열에 지나지 않아 보이나 json 타입임. 항상 ""를 사용함
# Out:
# [
#     {
#         "title": "어떻게 이별까지 사랑하겠어, 널 사랑하는 거지",
#         "album": "항해",
#         "artist": "AKMU (악동뮤지션)",
#         "rank": 1
#     },
#     {
#         "title": "새 사랑",
#         "album": "새 사랑",
#         "artist": "송하예",
#         "rank": 2
#     },
#     {
#         "title": "흔들리는 꽃들 속에서 네 샴푸향이 느껴진거야",
#         "album": "멜로가 체질 OST Part 3",
#         "artist": "장범준",
#         "rank": 3
#     },
#     {
#         "title": "떨어지는 낙엽까지도",
#         "album": "만추",
#         "artist": "헤이즈 (Heize)",
#         "rank": 4
#     },
#     {
#         "title": "있어줘요",
#         "album": "있어줘요",
#         "artist": "장덕철",
#         "rank": 5
#     },
#     {
#         "title": "조금 취했어 (Prod. 2soo)",
#         "album": "조금 취했어",
#         "artist": "임재현",
#         "rank": 6
#     },
#     {
#         "title": "허전해",
#         "album": "정규 2집 '마음, 하나'",
#         "artist": "폴킴",
#         "rank": 7
#     },
#     {
#         "title": "사랑이란 멜로는 없어",
#         "album": "사랑이란 멜로는 없어",
#         "artist": "전상근",
#         "rank": 8
#     },
#     {
#         "title": "워커홀릭",
#         "album": "Two Five",
#         "artist": "볼빨간사춘기",
#         "rank": 9
#     },
#     {
#         "title": "안녕",
#         "album": "호텔 델루나 OST Part.10",
#         "artist": "폴킴",
#         "rank": 10
#     },
#     {
#         "title": "오늘도 빛나는 너에게 (To You My Light) (Feat.이라온)",
#         "album": "Red Moon : To You My Light",
#         "artist": "마크툽 (MAKTUB)",
#         "rank": 11
#     },
#     {
#         "title": "시든 꽃에 물을 주듯",
#         "album": "시든 꽃에 물을 주듯",
#         "artist": "HYNN(박혜원)",
#         "rank": 12
#     },
#     {
#         "title": "가을밤 떠난 너",
#         "album": "Rewind",
#         "artist": "케이시 (Kassy)",
#         "rank": 13
#     },
#     {
#         "title": "Feel Special",
#         "album": "Feel Special",
#         "artist": "TWICE (트와이스)",
#         "rank": 14
#     },
#     {
#         "title": "니 소식",
#         "album": "니 소식",
#         "artist": "송하예",
#         "rank": 15
#     },
#     {
#         "title": "우리 어떻게 할까요",
#         "album": "사랑하는 그대에게 - The 2nd Mini Album",
#         "artist": "첸 (CHEN)",
#         "rank": 16
#     },
#     {
#         "title": "기억해줘요 내 모든 날과 그때를",
#         "album": "호텔 델루나 OST Part.7",
#         "artist": "거미",
#         "rank": 17
#     },
#     {
#         "title": "포장마차",
#         "album": "포장마차",
#         "artist": "황인욱",
#         "rank": 18
#     },
#     {
#         "title": "만추 (Feat. Crush)",
#         "album": "만추",
#         "artist": "헤이즈 (Heize)",
#         "rank": 19
#     },
#     {
#         "title": "가끔 이러다",
#         "album": "가끔 이러다",
#         "artist": "펀치 (Punch)",
#         "rank": 20
#     },
#     {
#         "title": "헤어지자 (Prod. 정키)",
#         "album": "soar",
#         "artist": "휘인 (Whee In)",
#         "rank": 21
#     },
#     {
#         "title": "2002",
#         "album": "Speak Your Mind (Deluxe)",
#         "artist": "Anne-Marie",
#         "rank": 22
#     },
#     {
#         "title": "Señorita",
#         "album": "Señorita",
#         "artist": "Shawn Mendes",
#         "rank": 23
#     },
#     {
#         "title": "천둥벌거숭이 (Feat. Jvcki Wai, 염따)",
#         "album": "THINKING Part.1",
#         "artist": "지코 (ZICO)",
#         "rank": 24
#     },
#     {
#         "title": "사랑에 연습이 있었다면 (Prod. 2soo)",
#         "album": "사랑에 연습이 있었다면",
#         "artist": "임재현",
#         "rank": 25
#     },
#     {
#         "title": "그대라는 시",
#         "album": "호텔 델루나 OST Part.3",
#         "artist": "태연 (TAEYEON)",
#         "rank": 26
#     },
#     {
#         "title": "술이 문제야",
#         "album": "술이 문제야",
#         "artist": "장혜진",
#         "rank": 27
#     },
#     {
#         "title": "사랑이 식었다고 말해도 돼",
#         "album": "사랑이 식었다고 말해도 돼",
#         "artist": "먼데이 키즈 (Monday Kiz)",
#         "rank": 28
#     },
#     {
#         "title": "작은 것들을 위한 시 (Boy With Luv) feat. Halsey",
#         "album": "MAP OF THE SOUL : PERSONA",
#         "artist": "방탄소년단",
#         "rank": 29
#     },
#     {
#         "title": "모든 날, 모든 순간 (Every day, Every Moment)",
#         "album": "`키스 먼저 할까요?` OST Part.3",
#         "artist": "폴킴",
#         "rank": 30
#     },
#     {
#         "title": "bad guy",
#         "album": "WHEN WE ALL FALL ASLEEP, WHERE DO WE GO?",
#         "artist": "Billie Eilish",
#         "rank": 31
#     },
#     {
#         "title": "호랑이소굴 (Feat. Jvcki Wai)",
#         "album": "호랑이소굴",
#         "artist": "기리보이",
#         "rank": 32
#     },
#     {
#         "title": "사람",
#         "album": "THINKING Part.1",
#         "artist": "지코 (ZICO)",
#         "rank": 33
#     },
#     {
#         "title": "이별행동",
#         "album": "이별행동",
#         "artist": "이우",
#         "rank": 34
#     },
#     {
#         "title": "다시 만날까 봐",
#         "album": "다시 만날까 봐",
#         "artist": "V.O.S",
#         "rank": 35
#     },
#     {
#         "title": "BAND",
#         "album": "BAND",
#         "artist": "창모 (CHANGMO)",
#         "rank": 36
#     },
#     {
#         "title": "헤어져줘서 고마워",
#         "album": "헤어져줘서 고마워",
#         "artist": "벤",
#         "rank": 37
#     },
#     {
#         "title": "복숭아",
#         "album": "스무 살의 봄",
#         "artist": "아이유",
#         "rank": 38
#     },
#     {
#         "title": "나의 어깨에 기대어요",
#         "album": "호텔 델루나 OST Part.2",
#         "artist": "10cm",
#         "rank": 39
#     },
#     {
#         "title": "Done For Me",
#         "album": "호텔 델루나 OST Part.12",
#         "artist": "펀치 (Punch)",
#         "rank": 40
#     },
#     {
#         "title": "내 목소리 들리니",
#         "album": "호텔 델루나 OST Part.9",
#         "artist": "벤",
#         "rank": 41
#     },
#     {
#         "title": "꽃처럼 예쁜 그대",
#         "album": "동백꽃 필 무렵 (KBS2 수목드라마) OST - Part.4",
#         "artist": "임한별",
#         "rank": 42
#     },
#     {
#         "title": "달",
#         "album": "항해",
#         "artist": "AKMU (악동뮤지션)",
#         "rank": 43
#     },
#     {
#         "title": "벗",
#         "album": "벗",
#         "artist": "닐로(Nilo)",
#         "rank": 44
#     },
#     {
#         "title": "Speechless (Full)",
#         "album": "Aladdin (Original Motion Picture Soundtrack)",
#         "artist": "Naomi Scott",
#         "rank": 45
#     },
#     {
#         "title": "사월이 지나면 우리 헤어져요 (Beautiful goodbye)",
#         "album": "사월, 그리고 꽃 - The 1st Mini Album",
#         "artist": "첸 (CHEN)",
#         "rank": 46
#     },
#     {
#         "title": "널 안지 않을 수 있어야지",
#         "album": "사랑하는 그대에게 - The 2nd Mini Album",
#         "artist": "첸 (CHEN)",
#         "rank": 47
#     },
#     {
#         "title": "너를 만나",
#         "album": "너를 만나",
#         "artist": "폴킴",
#         "rank": 48
#     },
#     {
#         "title": "사계 (Four Seasons)",
#         "album": "사계 (Four Seasons)",
#         "artist": "태연 (TAEYEON)",
#         "rank": 49
#     },
#     {
#         "title": "내 맘을 볼 수 있나요",
#         "album": "호텔 델루나 OST Part.5",
#         "artist": "헤이즈 (Heize)",
#         "rank": 50
#     },
#     {
#         "title": "날라리 (LALALAY)",
#         "album": "날라리 (LALALAY)",
#         "artist": "선미",
#         "rank": 51
#     },
#     {
#         "title": "우리 시작해도 괜찮을까요",
#         "album": "우리 시작해도 괜찮을까요",
#         "artist": "정준일",
#         "rank": 52
#     },
#     {
#         "title": "헤어질 자신 있니 (Narr. SBS 박선영 아나운서)",
#         "album": "헤어질 자신 있니",
#         "artist": "앤씨아",
#         "rank": 53
#     },
#     {
#         "title": "솔직하게 말해서 나",
#         "album": "솔직하게 말해서 나",
#         "artist": "김나영",
#         "rank": 54
#     },
#     {
#         "title": "너에게 못했던 내 마지막 말은",
#         "album": "너에게 못했던 내 마지막 말은",
#         "artist": "다비치",
#         "rank": 55
#     },
#     {
#         "title": "그때가 좋았어",
#         "album": "그때가 좋았어",
#         "artist": "케이시 (Kassy)",
#         "rank": 56
#     },
#     {
#         "title": "Paris In The Rain",
#         "album": "I met you when I was 18. (the playlist)",
#         "artist": "Lauv",
#         "rank": 57
#     },
#     {
#         "title": "노래방에서",
#         "album": "장범준 3집",
#         "artist": "장범준",
#         "rank": 58
#     },
#     {
#         "title": "내 안부",
#         "album": "내 안부",
#         "artist": "이우",
#         "rank": 59
#     },
#     {
#         "title": "나빠(NAPPA)",
#         "album": "나빠(NAPPA)",
#         "artist": "Crush",
#         "rank": 60
#     },
#     {
#         "title": "ICY",
#         "album": "IT`z ICY",
#         "artist": "ITZY (있지)",
#         "rank": 61
#     },
#     {
#         "title": "전화를 할까봐",
#         "album": "전화를 할까봐",
#         "artist": "오반",
#         "rank": 62
#     },
#     {
#         "title": "일기",
#         "album": "만추",
#         "artist": "헤이즈 (Heize)",
#         "rank": 63
#     },
#     {
#         "title": "FANCY",
#         "album": "FANCY YOU",
#         "artist": "TWICE (트와이스)",
#         "rank": 64
#     },
#     {
#         "title": "FREEDOM",
#         "album": "항해",
#         "artist": "AKMU (악동뮤지션)",
#         "rank": 65
#     },
#     {
#         "title": "FLASH",
#         "album": "비상 : QUANTUM LEAP",
#         "artist": "X1 (엑스원)",
#         "rank": 66
#     },
#     {
#         "title": "인사",
#         "album": "인사",
#         "artist": "멜로망스",
#         "rank": 67
#     },
#     {
#         "title": "가을속에서",
#         "album": "화실(化-室:atelier)",
#         "artist": "화사(Hwa Sa)",
#         "rank": 68
#     },
#     {
#         "title": "주저하는 연인들을 위해",
#         "album": "전설",
#         "artist": "잔나비",
#         "rank": 69
#     },
#     {
#         "title": "꿈속에 너 (Feat. 전상근)",
#         "album": "두 번째 이야기",
#         "artist": "에이치코드 (H:CODE)",
#         "rank": 70
#     },
#     {
#         "title": "Snapping",
#         "album": "Flourishing",
#         "artist": "청하",
#         "rank": 71
#     },
#     {
#         "title": "봄날",
#         "album": "YOU NEVER WALK ALONE",
#         "artist": "방탄소년단",
#         "rank": 72
#     },
#     {
#         "title": "그대에게",
#         "album": "사랑하는 그대에게 - The 2nd Mini Album",
#         "artist": "첸 (CHEN)",
#         "rank": 73
#     },
#     {
#         "title": "괜찮아도 괜찮아 (That`s okay)",
#         "album": "괜찮아도 괜찮아 (That`s okay) - SM STATION",
#         "artist": "디오 (D.O.)",
#         "rank": 74
#     },
#     {
#         "title": "가라사대",
#         "album": "The Movie Star",
#         "artist": "BewhY (비와이)",
#         "rank": 75
#     },
#     {
#         "title": "Believer",
#         "album": "Evolve",
#         "artist": "Imagine Dragons",
#         "rank": 76
#     },
#     {
#         "title": "물 만난 물고기",
#         "album": "항해",
#         "artist": "AKMU (악동뮤지션)",
#         "rank": 77
#     },
#     {
#         "title": "고운 그대는 시들지 않으리",
#         "album": "사랑하는 그대에게 - The 2nd Mini Album",
#         "artist": "첸 (CHEN)",
#         "rank": 78
#     },
#     {
#         "title": "담아 (Feat. 염따, pH-1) (Prod. BOYCOLD)",
#         "album": "쇼미더머니 8 Episode 1",
#         "artist": "스윙스",
#         "rank": 79
#     },
#     {
#         "title": "Another Day",
#         "album": "호텔 델루나 OST Part.1",
#         "artist": "먼데이 키즈 (Monday Kiz)",
#         "rank": 80
#     },
#     {
#         "title": "그댄 모르죠",
#         "album": "사랑하는 그대에게 - The 2nd Mini Album",
#         "artist": "첸 (CHEN)",
#         "rank": 81
#     },
#     {
#         "title": "IDOL",
#         "album": "LOVE YOURSELF 結 `Answer`",
#         "artist": "방탄소년단",
#         "rank": 82
#     },
#     {
#         "title": "사랑 둘",
#         "album": "사랑 둘",
#         "artist": "김필",
#         "rank": 83
#     },
#     {
#         "title": "밤 끝없는 밤",
#         "album": "항해",
#         "artist": "AKMU (악동뮤지션)",
#         "rank": 84
#     },
#     {
#         "title": "아퍼 (Feat. Kid Milli, Lil tachi, 김승민, NO:EL, C JAMM)",
#         "album": "100년제전문대학",
#         "artist": "기리보이",
#         "rank": 85
#     },
#     {
#         "title": "굿밤 (GOOD BAM)",
#         "album": "야호(夜好)",
#         "artist": "엔플라잉 (N.Flying)",
#         "rank": 86
#     },
#     {
#         "title": "나만 아픈 일",
#         "album": "나만 아픈 일",
#         "artist": "이해리 (다비치)",
#         "rank": 87
#     },
#     {
#         "title": "비",
#         "album": "비",
#         "artist": "폴킴",
#         "rank": 88
#     },
#     {
#         "title": "뱃노래",
#         "album": "항해",
#         "artist": "AKMU (악동뮤지션)",
#         "rank": 89
#     },
#     {
#         "title": "DAUM (Feat. Colde)",
#         "album": "만추",
#         "artist": "헤이즈 (Heize)",
#         "rank": 90
#     },
#     {
#         "title": "We don`t talk together (Feat. 기리보이) (Prod. SUGA)",
#         "album": "We don`t talk together",
#         "artist": "헤이즈 (Heize)",
#         "rank": 91
#     },
#     {
#         "title": "달라달라",
#         "album": "IT`z Different",
#         "artist": "ITZY (있지)",
#         "rank": 92
#     },
#     {
#         "title": "잘 자요",
#         "album": "사랑하는 그대에게 - The 2nd Mini Album",
#         "artist": "첸 (CHEN)",
#         "rank": 93
#     },
#     {
#         "title": "Goodbye",
#         "album": "Goodbye",
#         "artist": "박효신",
#         "rank": 94
#     },
#     {
#         "title": "음파음파 (Umpah Umpah)",
#         "album": "‘The ReVe Festival’ Day 2",
#         "artist": "Red Velvet (레드벨벳)",
#         "rank": 95
#     },
#     {
#         "title": "사계 (하루살이)",
#         "album": "Circular",
#         "artist": "엠씨더맥스",
#         "rank": 96
#     },
#     {
#         "title": "Love Shot",
#         "album": "LOVE SHOT - The 5th Album Repackage",
#         "artist": "EXO",
#         "rank": 97
#     },
#     {
#         "title": "XX",
#         "album": "Two Five",
#         "artist": "볼빨간사춘기",
#         "rank": 98
#     },
#     {
#         "title": "Way Back Home",
#         "album": "Take",
#         "artist": "숀 (SHAUN)",
#         "rank": 99
#     },
#     {
#         "title": "우리 만난다면",
#         "album": "낮과 밤",
#         "artist": "스무살",
#         "rank": 100
#     }
# ]

# %% [markdown]
# ## JSON lines 포맷
# * JSON 포맷에서는 데이터를 한번에 변환하지만, list 데이터를 개행("\n")으로 구분하여 JSON 포맷으로 구현한다.
# * CSV 포맷과 비교하여 json lines 포맷은 중첩된 데이터를 표현할 수 있다.
# * 데이터 append 시에 단순히 파일 끝에 추가하면 된다. 로그성 데이터에 편리하다.

# %%
import json
with open("melon_char.jsonl", "wt", encoding="utf8") as f:
    for song in song_list:
        json_string_for_song = json.dumps(song, ensure_ascii=False)
        f.write(json_string_for_song + "\n")

# %%
# JSON LINES 파일을 읽어서 객체로 변환
with open("melon_char.jsonl", "rt", encoding='utf8') as f:
    song_list = []
    for line in f:
        song = json.loads(line)
        song_list.append(song)

# %%
print(open("melon_char.jsonl", "rt", encoding="utf-8").read())
# Out:
# {"title": "어떻게 이별까지 사랑하겠어, 널 사랑하는 거지", "album": "항해", "artist": "AKMU (악동뮤지션)", "rank": 1}
# {"title": "새 사랑", "album": "새 사랑", "artist": "송하예", "rank": 2}
# {"title": "흔들리는 꽃들 속에서 네 샴푸향이 느껴진거야", "album": "멜로가 체질 OST Part 3", "artist": "장범준", "rank": 3}
# {"title": "떨어지는 낙엽까지도", "album": "만추", "artist": "헤이즈 (Heize)", "rank": 4}
# {"title": "있어줘요", "album": "있어줘요", "artist": "장덕철", "rank": 5}
# {"title": "조금 취했어 (Prod. 2soo)", "album": "조금 취했어", "artist": "임재현", "rank": 6}
# {"title": "허전해", "album": "정규 2집 '마음, 하나'", "artist": "폴킴", "rank": 7}
# {"title": "사랑이란 멜로는 없어", "album": "사랑이란 멜로는 없어", "artist": "전상근", "rank": 8}
# {"title": "워커홀릭", "album": "Two Five", "artist": "볼빨간사춘기", "rank": 9}
# {"title": "안녕", "album": "호텔 델루나 OST Part.10", "artist": "폴킴", "rank": 10}
# {"title": "오늘도 빛나는 너에게 (To You My Light) (Feat.이라온)", "album": "Red Moon : To You My Light", "artist": "마크툽 (MAKTUB)", "rank": 11}
# {"title": "시든 꽃에 물을 주듯", "album": "시든 꽃에 물을 주듯", "artist": "HYNN(박혜원)", "rank": 12}
# {"title": "가을밤 떠난 너", "album": "Rewind", "artist": "케이시 (Kassy)", "rank": 13}
# {"title": "Feel Special", "album": "Feel Special", "artist": "TWICE (트와이스)", "rank": 14}
# {"title": "니 소식", "album": "니 소식", "artist": "송하예", "rank": 15}
# {"title": "우리 어떻게 할까요", "album": "사랑하는 그대에게 - The 2nd Mini Album", "artist": "첸 (CHEN)", "rank": 16}
# {"title": "기억해줘요 내 모든 날과 그때를", "album": "호텔 델루나 OST Part.7", "artist": "거미", "rank": 17}
# {"title": "포장마차", "album": "포장마차", "artist": "황인욱", "rank": 18}
# {"title": "만추 (Feat. Crush)", "album": "만추", "artist": "헤이즈 (Heize)", "rank": 19}
# {"title": "가끔 이러다", "album": "가끔 이러다", "artist": "펀치 (Punch)", "rank": 20}
# {"title": "헤어지자 (Prod. 정키)", "album": "soar", "artist": "휘인 (Whee In)", "rank": 21}
# {"title": "2002", "album": "Speak Your Mind (Deluxe)", "artist": "Anne-Marie", "rank": 22}
# {"title": "Señorita", "album": "Señorita", "artist": "Shawn Mendes", "rank": 23}
# {"title": "천둥벌거숭이 (Feat. Jvcki Wai, 염따)", "album": "THINKING Part.1", "artist": "지코 (ZICO)", "rank": 24}
# {"title": "사랑에 연습이 있었다면 (Prod. 2soo)", "album": "사랑에 연습이 있었다면", "artist": "임재현", "rank": 25}
# {"title": "그대라는 시", "album": "호텔 델루나 OST Part.3", "artist": "태연 (TAEYEON)", "rank": 26}
# {"title": "술이 문제야", "album": "술이 문제야", "artist": "장혜진", "rank": 27}
# {"title": "사랑이 식었다고 말해도 돼", "album": "사랑이 식었다고 말해도 돼", "artist": "먼데이 키즈 (Monday Kiz)", "rank": 28}
# {"title": "작은 것들을 위한 시 (Boy With Luv) feat. Halsey", "album": "MAP OF THE SOUL : PERSONA", "artist": "방탄소년단", "rank": 29}
# {"title": "모든 날, 모든 순간 (Every day, Every Moment)", "album": "`키스 먼저 할까요?` OST Part.3", "artist": "폴킴", "rank": 30}
# {"title": "bad guy", "album": "WHEN WE ALL FALL ASLEEP, WHERE DO WE GO?", "artist": "Billie Eilish", "rank": 31}
# {"title": "호랑이소굴 (Feat. Jvcki Wai)", "album": "호랑이소굴", "artist": "기리보이", "rank": 32}
# {"title": "사람", "album": "THINKING Part.1", "artist": "지코 (ZICO)", "rank": 33}
# {"title": "이별행동", "album": "이별행동", "artist": "이우", "rank": 34}
# {"title": "다시 만날까 봐", "album": "다시 만날까 봐", "artist": "V.O.S", "rank": 35}
# {"title": "BAND", "album": "BAND", "artist": "창모 (CHANGMO)", "rank": 36}
# {"title": "헤어져줘서 고마워", "album": "헤어져줘서 고마워", "artist": "벤", "rank": 37}
# {"title": "복숭아", "album": "스무 살의 봄", "artist": "아이유", "rank": 38}
# {"title": "나의 어깨에 기대어요", "album": "호텔 델루나 OST Part.2", "artist": "10cm", "rank": 39}
# {"title": "Done For Me", "album": "호텔 델루나 OST Part.12", "artist": "펀치 (Punch)", "rank": 40}
# {"title": "내 목소리 들리니", "album": "호텔 델루나 OST Part.9", "artist": "벤", "rank": 41}
# {"title": "꽃처럼 예쁜 그대", "album": "동백꽃 필 무렵 (KBS2 수목드라마) OST - Part.4", "artist": "임한별", "rank": 42}
# {"title": "달", "album": "항해", "artist": "AKMU (악동뮤지션)", "rank": 43}
# {"title": "벗", "album": "벗", "artist": "닐로(Nilo)", "rank": 44}
# {"title": "Speechless (Full)", "album": "Aladdin (Original Motion Picture Soundtrack)", "artist": "Naomi Scott", "rank": 45}
# {"title": "사월이 지나면 우리 헤어져요 (Beautiful goodbye)", "album": "사월, 그리고 꽃 - The 1st Mini Album", "artist": "첸 (CHEN)", "rank": 46}
# {"title": "널 안지 않을 수 있어야지", "album": "사랑하는 그대에게 - The 2nd Mini Album", "artist": "첸 (CHEN)", "rank": 47}
# {"title": "너를 만나", "album": "너를 만나", "artist": "폴킴", "rank": 48}
# {"title": "사계 (Four Seasons)", "album": "사계 (Four Seasons)", "artist": "태연 (TAEYEON)", "rank": 49}
# {"title": "내 맘을 볼 수 있나요", "album": "호텔 델루나 OST Part.5", "artist": "헤이즈 (Heize)", "rank": 50}
# {"title": "날라리 (LALALAY)", "album": "날라리 (LALALAY)", "artist": "선미", "rank": 51}
# {"title": "우리 시작해도 괜찮을까요", "album": "우리 시작해도 괜찮을까요", "artist": "정준일", "rank": 52}
# {"title": "헤어질 자신 있니 (Narr. SBS 박선영 아나운서)", "album": "헤어질 자신 있니", "artist": "앤씨아", "rank": 53}
# {"title": "솔직하게 말해서 나", "album": "솔직하게 말해서 나", "artist": "김나영", "rank": 54}
# {"title": "너에게 못했던 내 마지막 말은", "album": "너에게 못했던 내 마지막 말은", "artist": "다비치", "rank": 55}
# {"title": "그때가 좋았어", "album": "그때가 좋았어", "artist": "케이시 (Kassy)", "rank": 56}
# {"title": "Paris In The Rain", "album": "I met you when I was 18. (the playlist)", "artist": "Lauv", "rank": 57}
# {"title": "노래방에서", "album": "장범준 3집", "artist": "장범준", "rank": 58}
# {"title": "내 안부", "album": "내 안부", "artist": "이우", "rank": 59}
# {"title": "나빠(NAPPA)", "album": "나빠(NAPPA)", "artist": "Crush", "rank": 60}
# {"title": "ICY", "album": "IT`z ICY", "artist": "ITZY (있지)", "rank": 61}
# {"title": "전화를 할까봐", "album": "전화를 할까봐", "artist": "오반", "rank": 62}
# {"title": "일기", "album": "만추", "artist": "헤이즈 (Heize)", "rank": 63}
# {"title": "FANCY", "album": "FANCY YOU", "artist": "TWICE (트와이스)", "rank": 64}
# {"title": "FREEDOM", "album": "항해", "artist": "AKMU (악동뮤지션)", "rank": 65}
# {"title": "FLASH", "album": "비상 : QUANTUM LEAP", "artist": "X1 (엑스원)", "rank": 66}
# {"title": "인사", "album": "인사", "artist": "멜로망스", "rank": 67}
# {"title": "가을속에서", "album": "화실(化-室:atelier)", "artist": "화사(Hwa Sa)", "rank": 68}
# {"title": "주저하는 연인들을 위해", "album": "전설", "artist": "잔나비", "rank": 69}
# {"title": "꿈속에 너 (Feat. 전상근)", "album": "두 번째 이야기", "artist": "에이치코드 (H:CODE)", "rank": 70}
# {"title": "Snapping", "album": "Flourishing", "artist": "청하", "rank": 71}
# {"title": "봄날", "album": "YOU NEVER WALK ALONE", "artist": "방탄소년단", "rank": 72}
# {"title": "그대에게", "album": "사랑하는 그대에게 - The 2nd Mini Album", "artist": "첸 (CHEN)", "rank": 73}
# {"title": "괜찮아도 괜찮아 (That`s okay)", "album": "괜찮아도 괜찮아 (That`s okay) - SM STATION", "artist": "디오 (D.O.)", "rank": 74}
# {"title": "가라사대", "album": "The Movie Star", "artist": "BewhY (비와이)", "rank": 75}
# {"title": "Believer", "album": "Evolve", "artist": "Imagine Dragons", "rank": 76}
# {"title": "물 만난 물고기", "album": "항해", "artist": "AKMU (악동뮤지션)", "rank": 77}
# {"title": "고운 그대는 시들지 않으리", "album": "사랑하는 그대에게 - The 2nd Mini Album", "artist": "첸 (CHEN)", "rank": 78}
# {"title": "담아 (Feat. 염따, pH-1) (Prod. BOYCOLD)", "album": "쇼미더머니 8 Episode 1", "artist": "스윙스", "rank": 79}
# {"title": "Another Day", "album": "호텔 델루나 OST Part.1", "artist": "먼데이 키즈 (Monday Kiz)", "rank": 80}
# {"title": "그댄 모르죠", "album": "사랑하는 그대에게 - The 2nd Mini Album", "artist": "첸 (CHEN)", "rank": 81}
# {"title": "IDOL", "album": "LOVE YOURSELF 結 `Answer`", "artist": "방탄소년단", "rank": 82}
# {"title": "사랑 둘", "album": "사랑 둘", "artist": "김필", "rank": 83}
# {"title": "밤 끝없는 밤", "album": "항해", "artist": "AKMU (악동뮤지션)", "rank": 84}
# {"title": "아퍼 (Feat. Kid Milli, Lil tachi, 김승민, NO:EL, C JAMM)", "album": "100년제전문대학", "artist": "기리보이", "rank": 85}
# {"title": "굿밤 (GOOD BAM)", "album": "야호(夜好)", "artist": "엔플라잉 (N.Flying)", "rank": 86}
# {"title": "나만 아픈 일", "album": "나만 아픈 일", "artist": "이해리 (다비치)", "rank": 87}
# {"title": "비", "album": "비", "artist": "폴킴", "rank": 88}
# {"title": "뱃노래", "album": "항해", "artist": "AKMU (악동뮤지션)", "rank": 89}
# {"title": "DAUM (Feat. Colde)", "album": "만추", "artist": "헤이즈 (Heize)", "rank": 90}
# {"title": "We don`t talk together (Feat. 기리보이) (Prod. SUGA)", "album": "We don`t talk together", "artist": "헤이즈 (Heize)", "rank": 91}
# {"title": "달라달라", "album": "IT`z Different", "artist": "ITZY (있지)", "rank": 92}
# {"title": "잘 자요", "album": "사랑하는 그대에게 - The 2nd Mini Album", "artist": "첸 (CHEN)", "rank": 93}
# {"title": "Goodbye", "album": "Goodbye", "artist": "박효신", "rank": 94}
# {"title": "음파음파 (Umpah Umpah)", "album": "‘The ReVe Festival’ Day 2", "artist": "Red Velvet (레드벨벳)", "rank": 95}
# {"title": "사계 (하루살이)", "album": "Circular", "artist": "엠씨더맥스", "rank": 96}
# {"title": "Love Shot", "album": "LOVE SHOT - The 5th Album Repackage", "artist": "EXO", "rank": 97}
# {"title": "XX", "album": "Two Five", "artist": "볼빨간사춘기", "rank": 98}
# {"title": "Way Back Home", "album": "Take", "artist": "숀 (SHAUN)", "rank": 99}
# {"title": "우리 만난다면", "album": "낮과 밤", "artist": "스무살", "rank": 100}

# %% [markdown]
# ## pickle 포멧
# * 파이썬 고유 직렬화 포맷으로 거의 모든 파이썬 데이터 타입을 지원한다.
# * 파이썬 버전별로 pickle 데이터가 상이할수 있음에 유의한다.
# * 데이터 객체를 한번에 변환하고 데이터 append 시에도 전체 변환이 필요하다.

# %%
import pickle

# song_list 객체를 한번에 pickle 포맷 데이터로 변환
pickle_data = pickle.dumps(song_list)

with open("melon_chart.pickle", "wb") as f:  # byte 형식으로 저장. 따라서 wb 모드로 저장해야 함
    f.write(pickle_data)

# %%
print(pickle_data)
# Out:
# b'\x80\x03]q\x00(}q\x01(X\x05\x00\x00\x00titleq\x02X?\x00\x00\x00\xec\x96\xb4\xeb\x96\xbb\xea\xb2\x8c \xec\x9d\xb4\xeb\xb3\x84\xea\xb9\x8c\xec\xa7\x80 \xec\x82\xac\xeb\x9e\x91\xed\x95\x98\xea\xb2\xa0\xec\x96\xb4, \xeb\x84\x90 \xec\x82\xac\xeb\x9e\x91\xed\x95\x98\xeb\x8a\x94 \xea\xb1\xb0\xec\xa7\x80q\x03X\x05\x00\x00\x00albumq\x04X\x06\x00\x00\x00\xed\x95\xad\xed\x95\xb4q\x05X\x06\x00\x00\x00artistq\x06X\x16\x00\x00\x00AKMU (\xec\x95\x85\xeb\x8f\x99\xeb\xae\xa4\xec\xa7\x80\xec\x85\x98)q\x07X\x04\x00\x00\x00rankq\x08K\x01u}q\t(X\x05\x00\x00\x00titleq\nX\n\x00\x00\x00\xec\x83\x88 \xec\x82\xac\xeb\x9e\x91q\x0bX\x05\x00\x00\x00albumq\x0cX\n\x00\x00\x00\xec\x83\x88 \xec\x82\xac\xeb\x9e\x91q\rX\x06\x00\x00\x00artistq\x0eX\t\x00\x00\x00\xec\x86\xa1\xed\x95\x98\xec\x98\x88q\x0fX\x04\x00\x00\x00rankq\x10K\x02u}q\x11(X\x05\x00\x00\x00titleq\x12X>\x00\x00\x00\xed\x9d\x94\xeb\x93\xa4\xeb\xa6\xac\xeb\x8a\x94 \xea\xbd\x83\xeb\x93\xa4 \xec\x86\x8d\xec\x97\x90\xec\x84\x9c \xeb\x84\xa4 \xec\x83\xb4\xed\x91\xb8\xed\x96\xa5\xec\x9d\xb4 \xeb\x8a\x90\xea\xbb\xb4\xec\xa7\x84\xea\xb1\xb0\xec\x95\xbcq\x13X\x05\x00\x00\x00albumq\x14X\x1b\x00\x00\x00\xeb\xa9\x9c\xeb\xa1\x9c\xea\xb0\x80 \xec\xb2\xb4\xec\xa7\x88 OST Part 3q\x15X\x06\x00\x00\x00artistq\x16X\t\x00\x00\x00\xec\x9e\xa5\xeb\xb2\x94\xec\xa4\x80q\x17X\x04\x00\x00\x00rankq\x18K\x03u}q\x19(X\x05\x00\x00\x00titleq\x1aX\x1c\x00\x00\x00\xeb\x96\xa8\xec\x96\xb4\xec\xa7\x80\xeb\x8a\x94 \xeb\x82\x99\xec\x97\xbd\xea\xb9\x8c\xec\xa7\x80\xeb\x8f\x84q\x1bX\x05\x00\x00\x00albumq\x1cX\x06\x00\x00\x00\xeb\xa7\x8c\xec\xb6\x94q\x1dX\x06\x00\x00\x00artistq\x1eX\x11\x00\x00\x00\xed\x97\xa4\xec\x9d\xb4\xec\xa6\x88 (Heize)q\x1fX\x04\x00\x00\x00rankq K\x04u}q!(X\x05\x00\x00\x00titleq"X\x0c\x00\x00\x00\xec\x9e\x88\xec\x96\xb4\xec\xa4\x98\xec\x9a\x94q#X\x05\x00\x00\x00albumq$X\x0c\x00\x00\x00\xec\x9e\x88\xec\x96\xb4\xec\xa4\x98\xec\x9a\x94q%X\x06\x00\x00\x00artistq&X\t\x00\x00\x00\xec\x9e\xa5\xeb\x8d\x95\xec\xb2\xa0q\'X\x04\x00\x00\x00rankq(K\x05u}q)(X\x05\x00\x00\x00titleq*X\x1d\x00\x00\x00\xec\xa1\xb0\xea\xb8\x88 \xec\xb7\xa8\xed\x96\x88\xec\x96\xb4 (Prod. 2soo)q+X\x05\x00\x00\x00albumq,X\x10\x00\x00\x00\xec\xa1\xb0\xea\xb8\x88 \xec\xb7\xa8\xed\x96\x88\xec\x96\xb4q-X\x06\x00\x00\x00artistq.X\t\x00\x00\x00\xec\x9e\x84\xec\x9e\xac\xed\x98\x84q/X\x04\x00\x00\x00rankq0K\x06u}q1(X\x05\x00\x00\x00titleq2X\t\x00\x00\x00\xed\x97\x88\xec\xa0\x84\xed\x95\xb4q3X\x05\x00\x00\x00albumq4X\x1c\x00\x00\x00\xec\xa0\x95\xea\xb7\x9c 2\xec\xa7\x91 \'\xeb\xa7\x88\xec\x9d\x8c, \xed\x95\x98\xeb\x82\x98\'q5X\x06\x00\x00\x00artistq6X\x06\x00\x00\x00\xed\x8f\xb4\xed\x82\xb4q7X\x04\x00\x00\x00rankq8K\x07u}q9(X\x05\x00\x00\x00titleq:X\x1d\x00\x00\x00\xec\x82\xac\xeb\x9e\x91\xec\x9d\xb4\xeb\x9e\x80 \xeb\xa9\x9c\xeb\xa1\x9c\xeb\x8a\x94 \xec\x97\x86\xec\x96\xb4q;X\x05\x00\x00\x00albumq<X\x1d\x00\x00\x00\xec\x82\xac\xeb\x9e\x91\xec\x9d\xb4\xeb\x9e\x80 \xeb\xa9\x9c\xeb\xa1\x9c\xeb\x8a\x94 \xec\x97\x86\xec\x96\xb4q=X\x06\x00\x00\x00artistq>X\t\x00\x00\x00\xec\xa0\x84\xec\x83\x81\xea\xb7\xbcq?X\x04\x00\x00\x00rankq@K\x08u}qA(X\x05\x00\x00\x00titleqBX\x0c\x00\x00\x00\xec\x9b\x8c\xec\xbb\xa4\xed\x99\x80\xeb\xa6\xadqCX\x05\x00\x00\x00albumqDX\x08\x00\x00\x00Two FiveqEX\x06\x00\x00\x00artistqFX\x12\x00\x00\x00\xeb\xb3\xbc\xeb\xb9\xa8\xea\xb0\x84\xec\x82\xac\xec\xb6\x98\xea\xb8\xb0qGX\x04\x00\x00\x00rankqHK\tu}qI(X\x05\x00\x00\x00titleqJX\x06\x00\x00\x00\xec\x95\x88\xeb\x85\x95qKX\x05\x00\x00\x00albumqLX\x1c\x00\x00\x00\xed\x98\xb8\xed\x85\x94 \xeb\x8d\xb8\xeb\xa3\xa8\xeb\x82\x98 OST Part.10qMX\x06\x00\x00\x00artistqNX\x06\x00\x00\x00\xed\x8f\xb4\xed\x82\xb4qOX\x04\x00\x00\x00rankqPK\nu}qQ(X\x05\x00\x00\x00titleqRX@\x00\x00\x00\xec\x98\xa4\xeb\x8a\x98\xeb\x8f\x84 \xeb\xb9\x9b\xeb\x82\x98\xeb\x8a\x94 \xeb\x84\x88\xec\x97\x90\xea\xb2\x8c (To You My Light) (Feat.\xec\x9d\xb4\xeb\x9d\xbc\xec\x98\xa8)qSX\x05\x00\x00\x00albumqTX\x1a\x00\x00\x00Red Moon : To You My LightqUX\x06\x00\x00\x00artistqVX\x12\x00\x00\x00\xeb\xa7\x88\xed\x81\xac\xed\x88\xbd (MAKTUB)qWX\x ...

# %%
with open("melon_chart.pickle", 'rb') as f:
    pickle_data = f.read()
    song_list = pickle.loads(pickle_data)

# %%
print(song_list)
# Out:
# [{'title': '어떻게 이별까지 사랑하겠어, 널 사랑하는 거지', 'album': '항해', 'artist': 'AKMU (악동뮤지션)', 'rank': 1}, {'title': '새 사랑', 'album': '새 사랑', 'artist': '송하예', 'rank': 2}, {'title': '흔들리는 꽃들 속에서 네 샴푸향이 느껴진거야', 'album': '멜로가 체질 OST Part 3', 'artist': '장범준', 'rank': 3}, {'title': '떨어지는 낙엽까지도', 'album': '만추', 'artist': '헤이즈 (Heize)', 'rank': 4}, {'title': '있어줘요', 'album': '있어줘요', 'artist': '장덕철', 'rank': 5}, {'title': '조금 취했어 (Prod. 2soo)', 'album': '조금 취했어', 'artist': '임재현', 'rank': 6}, {'title': '허전해', 'album': "정규 2집 '마음, 하나'", 'artist': '폴킴', 'rank': 7}, {'title': '사랑이란 멜로는 없어', 'album': '사랑이란 멜로는 없어', 'artist': '전상근', 'rank': 8}, {'title': '워커홀릭', 'album': 'Two Five', 'artist': '볼빨간사춘기', 'rank': 9}, {'title': '안녕', 'album': '호텔 델루나 OST Part.10', 'artist': '폴킴', 'rank': 10}, {'title': '오늘도 빛나는 너에게 (To You My Light) (Feat.이라온)', 'album': 'Red Moon : To You My Light', 'artist': '마크툽 (MAKTUB)', 'rank': 11}, {'title': '시든 꽃에 물을 주듯', 'album': '시든 꽃에 물을 주듯', 'artist': 'HYNN(박혜원)', 'rank': 12}, {'title': '가을밤 떠난 너', 'album': 'Rewind', 'artist': '케이시 (Kassy)', 'rank': 13}, {'title': 'Feel Special', 'album': 'Feel Special', 'artist': 'TWICE (트와이스)', 'rank': 14}, {'title': '니 소식', 'album': '니 소식', 'artist': '송하예', 'rank': 15}, {'title': '우리 어떻게 할까요', 'album': '사랑하는 그대에게 - The 2nd Mini Album', 'artist': '첸 (CHEN)', 'rank': 16}, {'title': '기억해줘요 내 모든 날과 그때를', 'album': '호텔 델루나 OST Part.7', 'artist': '거미', 'rank': 17}, {'title': '포장마차', 'album': '포장마차', 'artist': '황인욱', 'rank': 18}, {'title': '만추 (Feat. Crush)', 'album': '만추', 'artist': '헤이즈 (Heize)', 'rank': 19}, {'title': '가끔 이러다', 'album': '가끔 이러다', 'artist': '펀치 (Punch)', 'rank': 20}, {'title': '헤어지자 (Prod. 정키)', 'album': 'soar', 'artist': '휘인 (Whee In)', 'rank': 21}, {'title': '2002', 'album': 'Speak Your Mind (Deluxe)', 'artist': 'Anne-Marie', 'rank': 22}, {'title': 'Señorita', 'album': 'Señorita', 'artist': 'Shawn Mendes', 'rank': 23}, {'title': '천둥벌거숭이 (Feat. Jvcki Wai, 염따)', 'album': 'THINKING Part.1', 'artist': '지코 (ZICO)', 'rank': 24}, {'title': '사랑에 연습이 있었다면 (Prod. 2soo)', 'album': '사랑에 연습이 있었다면', 'artist': '임재현', 'rank': 25}, {'title': '그대라는 시', 'album': '호텔 델루나 OST Part.3', 'artist': '태연 (TAEYEON)', 'rank': 26}, {'title': '술이 문제야', 'album': '술이 문제야', 'artist': '장혜진', 'rank': 27}, {'title': '사랑이 식었다고 말해도 돼', 'album': '사랑이 식었다고 말해도 돼', 'artist': '먼데이 키즈 (Monday Kiz)', 'rank': 28}, {'title': '작은 것들을 위한 시 (Boy With Luv) feat. Halsey', 'album': 'MAP OF THE SOUL : PERSONA', 'artist': '방탄소년단', 'rank': 29}, {'title': '모든 날, 모든 순간 (Every day, Every Moment)', 'album': '`키스 먼저 할까요?` OST Part.3', 'artist': '폴킴', 'rank': 30}, {'title': 'bad guy', 'album': 'WHEN WE ALL FALL ASLEEP, WHERE DO WE GO?', 'artist': 'Billie Eilish', 'rank': 31}, {'title': '호랑이소굴 (Feat. Jvcki Wai)', 'album': '호랑이소굴', 'artist': '기리보이', 'rank': 32}, {'title': '사람', 'album': 'THINKING Part.1', 'artist': '지코 (ZICO)', 'rank': 33}, {'title': '이별행동', 'album': '이별행동', 'artist': '이우', 'rank': 34}, {'title': '다시 만날까 봐', 'album': '다시 만날까 봐', 'artist': 'V.O.S', 'rank': 35}, {'title': 'BAND', 'album': 'BAND', 'artist': '창모 (CHANGMO)', 'rank': 36}, {'title': '헤어져줘서 고마워', 'album': '헤어져줘서 고마워', 'artist': '벤', 'rank': 37}, {'title': '복숭아', 'album': '스무 살의 봄', 'artist': '아이유', 'rank': 38}, {'title': '나의 어깨에 기대어요', 'album': '호텔 델루나 OST Part.2', 'artist': '10cm', 'rank': 39}, {'title': 'Done For Me', 'album': '호텔 델루나 OST Part.12', 'artist': '펀치 (Punch)', 'rank': 40}, {'title': '내 목소리 들리니', 'album': '호텔 델루나 OST Part.9', 'artist': '벤', 'rank': 41}, {'title': '꽃처럼 예쁜 그대', 'album': '동백꽃 필 무렵 (KBS2 수목드라마) OST - Part.4', 'artist': '임한별', 'rank': 42}, {'title': '달', 'album': '항해', 'artist': 'AKMU (악동뮤지션)', 'rank': 43}, {'title': '벗', 'album': '벗', 'artist': '닐로(Nilo)', 'rank': 44}, {'title': 'Speechless (Full)', 'album': 'Aladdin (Original Motion Picture Soundtrack)', 'artist': 'Naomi Scott', 'rank': 45}, {'title': '사월이 지나면 우리 헤어져요 (Beautiful goodbye)', 'album': '사월, 그리고 꽃 - The 1st Mini Album', 'artist': '첸 (CHEN)', 'rank': 46}, {'title': '널 안지 않을 수 있어야지 ...

# %% [markdown]
# ## CSV/엑셀 포맷을 지원하는 다양한 라이브러리
# * pyopenxl
# * xlrd/xlwt
# * pandas : DataFrame 객체에 대해 csv/excel/pickle/json/sql/dict 포맷으로의 저장을 지원. excel 포맷의 경우 내부적으로 xlrd/xlwt를 활용한다.
# * pyexcel
# * xlwings

# %% [markdown]
# ### pyexcel을 활용하여 엑셀로 저장
# * 설치 : pip install pyexcel

# %%
import pyexcel

# %%
pyexcel.save_as(records=song_list, dest_file_name="melon_by_pyexcel.xls")

# %%
# 파일 생성을 위해 pyexcel-xlsxw 설치 필요
# !pip install pyexcel-xlsxw
# Out:
# Requirement already satisfied: pyexcel-xlsxw in /Users/imjunghee/anaconda3/lib/python3.7/site-packages (0.4.2)
# Requirement already satisfied: XlsxWriter==0.9.3 in /Users/imjunghee/anaconda3/lib/python3.7/site-packages (from pyexcel-xlsxw) (0.9.3)
# Requirement already satisfied: pyexcel-io>=0.4.0 in /Users/imjunghee/anaconda3/lib/python3.7/site-packages (from pyexcel-xlsxw) (0.5.20)
# Requirement already satisfied: lml>=0.0.4 in /Users/imjunghee/anaconda3/lib/python3.7/site-packages (from pyexcel-io>=0.4.0->pyexcel-xlsxw) (0.0.9)

# %% [markdown]
# ### pandas

# %%
# !pip install openpyxl
# Out:
# Requirement already satisfied: openpyxl in /Users/imjunghee/anaconda3/lib/python3.7/site-packages (3.0.0)
# Requirement already satisfied: jdcal in /Users/imjunghee/anaconda3/lib/python3.7/site-packages (from openpyxl) (1.4.1)
# Requirement already satisfied: et-xmlfile in /Users/imjunghee/anaconda3/lib/python3.7/site-packages (from openpyxl) (1.0.1)

# %%
import pandas as pd

df = pd.DataFrame(song_list)
df.to_excel('melon_chart.xlsx')
df.to_csv('melon_chart.csv')
df.to_pickle('melon_chart.pickle')
# Out:
# /Users/imjunghee/anaconda3/lib/python3.7/site-packages/pandas/compat/_optional.py:106: UserWarning: Pandas requires version '0.9.8' or newer of 'xlsxwriter' (version '0.9.3' currently installed).
#   warnings.warn(msg, UserWarning)

# %%
df = pd.read_excel('melon_chart.xlsx')
df = pd.read_csv('melon_chart.csv')
df = pd.read_pickle("melon_chart.pickle")

# %%
with open("melon_chart.csv", "rt", encoding="utf8") as f:
    print(f.read())
# Out:
# ,title,album,artist,rank
# 0,"어떻게 이별까지 사랑하겠어, 널 사랑하는 거지",항해,AKMU (악동뮤지션),1
# 1,새 사랑,새 사랑,송하예,2
# 2,흔들리는 꽃들 속에서 네 샴푸향이 느껴진거야,멜로가 체질 OST Part 3,장범준,3
# 3,떨어지는 낙엽까지도,만추,헤이즈 (Heize),4
# 4,있어줘요,있어줘요,장덕철,5
# 5,조금 취했어 (Prod. 2soo),조금 취했어,임재현,6
# 6,허전해,"정규 2집 '마음, 하나'",폴킴,7
# 7,사랑이란 멜로는 없어,사랑이란 멜로는 없어,전상근,8
# 8,워커홀릭,Two Five,볼빨간사춘기,9
# 9,안녕,호텔 델루나 OST Part.10,폴킴,10
# 10,오늘도 빛나는 너에게 (To You My Light) (Feat.이라온),Red Moon : To You My Light,마크툽 (MAKTUB),11
# 11,시든 꽃에 물을 주듯,시든 꽃에 물을 주듯,HYNN(박혜원),12
# 12,가을밤 떠난 너,Rewind,케이시 (Kassy),13
# 13,Feel Special,Feel Special,TWICE (트와이스),14
# 14,니 소식,니 소식,송하예,15
# 15,우리 어떻게 할까요,사랑하는 그대에게 - The 2nd Mini Album,첸 (CHEN),16
# 16,기억해줘요 내 모든 날과 그때를,호텔 델루나 OST Part.7,거미,17
# 17,포장마차,포장마차,황인욱,18
# 18,만추 (Feat. Crush),만추,헤이즈 (Heize),19
# 19,가끔 이러다,가끔 이러다,펀치 (Punch),20
# 20,헤어지자 (Prod. 정키),soar,휘인 (Whee In),21
# 21,2002,Speak Your Mind (Deluxe),Anne-Marie,22
# 22,Señorita,Señorita,Shawn Mendes,23
# 23,"천둥벌거숭이 (Feat. Jvcki Wai, 염따)",THINKING Part.1,지코 (ZICO),24
# 24,사랑에 연습이 있었다면 (Prod. 2soo),사랑에 연습이 있었다면,임재현,25
# 25,그대라는 시,호텔 델루나 OST Part.3,태연 (TAEYEON),26
# 26,술이 문제야,술이 문제야,장혜진,27
# 27,사랑이 식었다고 말해도 돼,사랑이 식었다고 말해도 돼,먼데이 키즈 (Monday Kiz),28
# 28,작은 것들을 위한 시 (Boy With Luv) feat. Halsey,MAP OF THE SOUL : PERSONA,방탄소년단,29
# 29,"모든 날, 모든 순간 (Every day, Every Moment)",`키스 먼저 할까요?` OST Part.3,폴킴,30
# 30,bad guy,"WHEN WE ALL FALL ASLEEP, WHERE DO WE GO?",Billie Eilish,31
# 31,호랑이소굴 (Feat. Jvcki Wai),호랑이소굴,기리보이,32
# 32,사람,THINKING Part.1,지코 (ZICO),33
# 33,이별행동,이별행동,이우,34
# 34,다시 만날까 봐,다시 만날까 봐,V.O.S,35
# 35,BAND,BAND,창모 (CHANGMO),36
# 36,헤어져줘서 고마워,헤어져줘서 고마워,벤,37
# 37,복숭아,스무 살의 봄,아이유,38
# 38,나의 어깨에 기대어요,호텔 델루나 OST Part.2,10cm,39
# 39,Done For Me,호텔 델루나 OST Part.12,펀치 (Punch),40
# 40,내 목소리 들리니,호텔 델루나 OST Part.9,벤,41
# 41,꽃처럼 예쁜 그대,동백꽃 필 무렵 (KBS2 수목드라마) OST - Part.4,임한별,42
# 42,달,항해,AKMU (악동뮤지션),43
# 43,벗,벗,닐로(Nilo),44
# 44,Speechless (Full),Aladdin (Original Motion Picture Soundtrack),Naomi Scott,45
# 45,사월이 지나면 우리 헤어져요 (Beautiful goodbye),"사월, 그리고 꽃 - The 1st Mini Album",첸 (CHEN),46
# 46,널 안지 않을 수 있어야지,사랑하는 그대에게 - The 2nd Mini Album,첸 (CHEN),47
# 47,너를 만나,너를 만나,폴킴,48
# 48,사계 (Four Seasons),사계 (Four Seasons),태연 (TAEYEON),49
# 49,내 맘을 볼 수 있나요,호텔 델루나 OST Part.5,헤이즈 (Heize),50
# 50,날라리 (LALALAY),날라리 (LALALAY),선미,51
# 51,우리 시작해도 괜찮을까요,우리 시작해도 괜찮을까요,정준일,52
# 52,헤어질 자신 있니 (Narr. SBS 박선영 아나운서),헤어질 자신 있니,앤씨아,53
# 53,솔직하게 말해서 나,솔직하게 말해서 나,김나영,54
# 54,너에게 못했던 내 마지막 말은,너에게 못했던 내 마지막 말은,다비치,55
# 55,그때가 좋았어,그때가 좋았어,케이시 (Kassy),56
# 56,Paris In The Rain,I met you when I was 18. (the playlist),Lauv,57
# 57,노래방에서,장범준 3집,장범준,58
# 58,내 안부,내 안부,이우,59
# 59,나빠(NAPPA),나빠(NAPPA),Crush,60
# 60,ICY,IT`z ICY,ITZY (있지),61
# 61,전화를 할까봐,전화를 할까봐,오반,62
# 62,일기,만추,헤이즈 (Heize),63
# 63,FANCY,FANCY YOU,TWICE (트와이스),64
# 64,FREEDOM,항해,AKMU (악동뮤지션),65
# 65,FLASH,비상 : QUANTUM LEAP,X1 (엑스원),66
# 66,인사,인사,멜로망스,67
# 67,가을속에서,화실(化-室:atelier),화사(Hwa Sa),68
# 68,주저하는 연인들을 위해,전설,잔나비,69
# 69,꿈속에 너 (Feat. 전상근),두 번째 이야기,에이치코드 (H:CODE),70
# 70,Snapping,Flourishing,청하,71
# 71,봄날,YOU NEVER WALK ALONE,방탄소년단,72
# 72,그대에게,사랑하는 그대에게 - The 2nd Mini Album,첸 (CHEN),73
# 73,괜찮아도 괜찮아 (That`s okay),괜찮아도 괜찮아 (That`s okay) - SM STATION,디오 (D.O.),74
# 74,가라사대,The Movie Star,BewhY (비와이),75
# 75,Believer,Evolve,Imagine Dragons,76
# 76,물 만난 물고기,항해,AKMU (악동뮤지션),77
# 77,고운 그대는 시들지 않으리,사랑하는 그대에게 - The 2nd Mini Album,첸 (CHEN),78
# 78,"담아 (Feat. 염따, pH-1) (Prod. BOYCOLD)",쇼미더머니 8 Episode 1,스윙스,79
# 79,Another Day,호텔 델루나 OST Part.1,먼데이 키즈 (Monday Kiz),80
# 80,그댄 모르죠,사랑하는 그대에게 - The 2nd Mini Album,첸 (CHEN),81
# 81,IDOL,LOVE YOURSELF 結 `Answer`,방탄소년단,82
# 82,사랑 둘,사랑 둘,김필,83
# 83,밤 끝없는 밤,항해,AKMU (악동뮤지션),84
# 84,"아퍼 (Feat. Kid Milli, Lil tachi, 김승민, NO:EL, C JAMM)",100년제전문대학,기리보이,85
# 85,굿밤 (GOOD BAM),야호(夜好),엔플라잉 (N.Flying),86
# 86,나만 아픈 일,나만 아픈 일,이해리 (다비치),87
# 87,비,비,폴킴,88
# 88,뱃노래,항해,AKMU (악동뮤지션),89
# 89,DAUM (Feat. Colde),만추,헤이즈 (Heize),90
# 90,We don`t talk together (Feat. 기리보이) (Prod. SUGA),We don`t talk together,헤이즈 (Heize),91
# 91,달라달라,IT`z Different,ITZY (있지),92
# 92,잘 자요,사랑하는 그대에게 - The 2nd Mini Album,첸 (CHEN),93
# 93,Goodbye,Goodbye,박효신,94
# 94,음파음파 (Umpah Umpah),‘The ReVe Festival’ Day 2,Red Velvet (레드벨벳),95
# 95,사계 (하루살이),Circular,엠씨더맥스,96
# 96,Love Shot,LOVE SHOT - The 5th Album Repackage,EXO,97
# 97,XX,Two Five,볼빨간사춘기,98
# 98,Way Back Home,Take,숀 (SHAUN),99
# 99,우리 만난다면,낮과 밤,스무살,100

# %% [markdown]
# ## 다양한 데이터베이스
# * RDB(관계형 데이터베이스) : SQLite, PostgreSQL, MySQL, Oracle, MSSQL 등
# * NoSQL : MongoDB, CouchDB, HBase, Redis

# %% [markdown]
# ### SQLite
# * 파일 데이터베이스
# * Single User 전용 : 멀티 프로세스/쓰레드에 의해 다중 처리 시에 Database Lock 등의 오류 발생 여지가 있다.

# %% [markdown]
# ### 파이썬 3 기본에서의 sqlite3 지원

# %%
import sqlite3

# 1. 연결
conn = sqlite3.connect('ex1.db')

# %%
c = conn.cursor()

# %%
# 2. 초기에 테이블 생성
c.execute('''CREATE TABLE stocks
            (date text, trans text, symbol text, qty real, price real)''') # 필드명 + 타입명

# %%
# 3. 데이터 1 Row 추가
c.execute("INSERT INTO stocks VALUES ('2006-01-05', 'BUY', 'RHAT', 100, 35.14)")

# %%
# 4. 변화를 저장
conn.commit()

# %%
# 5. 연결 닫기
conn.close()

# %% [markdown]
# ### 기본 Context Manager를 통한 접근

# %%
import sqlite3

with sqlite3.connect('ex2.db') as conn:
    cursor = conn.cursor()
    
    cursor.execute('''CREATE TABLE stocks
                        (date text, trans text, symbol text, qty real, price real)''')
    cursor.execute('''INSERT INTO stocks VALUES
                        ('2006-01-05', 'BUY', 'RHAT', 100, 35.14)''')

# %% [markdown]
# #### 위의 코드보다 조금 향상된 코드
#
# * 예외가 발생하면 conn.rollback( ) 수행
# * 그렇지 않으면 conn.commit( ) 수행

# %%
# 커스텀 context manager를 통한 구현
import sqlite3
from contextlib import contextmanager

@contextmanager
def sqlite_cursor(db_path):
    conn = sqlite3.connect(db_path)
    conn.set_trace_callback(print)  # 실행된 SQL 내역 출력
    cursor = conn.cursor()
    try:
        yield cursor
    except Exception as e:
        conn.rollback()
        raise
    finally:
        conn.commit()
    conn.close()

# %%
# 적용 예
with sqlite_cursor('ex5.db') as cursor:
    cursor.execute('CREATE TABLE stocks (date text, trans text, symbol text, qty real, price real)')
    cursor.execute("INSERT INTO stocks VALUES ('2006-01-05', 'BUY', 'RHAT', 100, 35.14)")
# Out:
# CREATE TABLE stocks (date text, trans text, symbol text, qty real, price real)
# BEGIN
# INSERT INTO stocks VALUES ('2006-01-05', 'BUY', 'RHAT', 100, 35.14)
# COMMIT

# %% [markdown]
# ## execute many

# %%
with sqlite_cursor('ex5.db') as cursor:
    purchases = [
        ('2006-03-08', 'BUY', 'IBM', 1000, 45.00),
        ('2006-04-05', 'BUY', 'MSFT', 1000, 72.00),
        ('2006-04-06', 'SELL', 'IBM', 500, 53.00),
    ]
    
    cursor.executemany('INSERT INTO stocks VALUES (?, ?, ?, ?, ?)', purchases)  # ? = placeholder
# Out:
# BEGIN
# INSERT INTO stocks VALUES ('2006-03-08', 'BUY', 'IBM', 1000, 45.0)
# INSERT INTO stocks VALUES ('2006-04-05', 'BUY', 'MSFT', 1000, 72.0)
# INSERT INTO stocks VALUES ('2006-04-06', 'SELL', 'IBM', 500, 53.0)
# COMMIT

# %% [markdown]
# ## 조건 조회 - parameterized Query(로그인을 처리하는 SQL)

# %% [raw]
# with sqlite_cursor('ex5.db') as cursor:
#     username = "'OR 1=1 --" # 위와 동일
#     password = ''
#
#     sq1 = "SELECT * FROM users WHERE username='%s' AND password='%s'"  # 공격에 취약
#     cursor.execute(sql % (username, password))
#     print(cursor.fetchone())
#
#     # ? placeholder
#     sql = "SELECT * FROM users WHERE username=? AND password=?"
#     cursor.execute(sql, (username, password))
#     print(cursor.fetchone())
#
#     # Named Placeholder
#     sql = "SELECT * FROM users WHERE username=:username AND password=:password"
#     cursor.execute(sql, {'username': username, 'password': password})
#     print(cursor.fetchone())

# %% [raw]
# ## 출력부분 : SQL Injection 공격에 취약
#
# SELECT * FROM users WHERE username='' OR 1=1 --' AND password='' )('admin', 'adminpw')
#
# ## SQL Injection 공격에 대응
# SELECT * FROM users WHERE username=''' OR 1=1 --' AND password='' None
# SELECT * FROM users WHERE username=''' OR 1=1 --' AND password=' None

# %% [markdown]
# ## 다양한 ORM
#
# ORM : 데이터 베이스와 객체 지향 프로그래밍 언어간의 호환되지 않는 데이터를 변환하는 프로그래밍 기법
# * Django ORM : 풀스택 웹프레임워크에 포함된 ORM
# * SQLAlchemy : 데이터베이스 툴킷
# * dataset : databases for lazy people (편리!!)

# %% [markdown]
# ### dataset
# * 설치 : pip install dataset
# * 특징
#     * Automatic schema 지원 : 테이블/컬럼이 없을 때 자동으로 생성
#     * Upserts 지원 : 추가하려는 데이터가 있다면 업데이트하고, 없으면 insert를 한다.
#     * 쉬운 Query 헬퍼 지원
#     * 호환성 : SQLAlchemy 기반으로 구현되었기 때문에 주요 DB들을 지원

# %% [markdown]
# ### dataset 예시(1)

# %%
import dataset

# %%
db = dataset.connect('sqlite:///mydatabase.db')  # db에 대한 커넥션 발생

table = db['sometable']  # table 명을 지정하면 이미 있으면 그걸 쓰고, 없으면 새로 생성한다.
table.insert(dict(name='John Doe', age=37))  # insert 말고 upsert도 사용가능
table.insert(dict(name='Jane Doe', age=34, gender='female'))

john = table.find_one(name='John Doe')

for row in table.all():
    print(row)
# Out:
# OrderedDict([('id', 1), ('name', 'John Doe'), ('age', 37), ('gender', None)])
# OrderedDict([('id', 2), ('name', 'Jane Doe'), ('age', 34), ('gender', 'female')])

# %% [markdown]
# ### dataset를 쓰지 않을 경우

# %% [raw]
# conn = sqlite3.connect(':memory')
# c = conn.cursor()
#
# c.execute('CREATE TABLE IF NOT EXISTS sometable (name, age, INTEGER)')
# conn.commit()
#
# c.execute('INSERT INTO sometable VALUES (?, ?)', ('John Doe', 37))
# conn.commit()
#
# c.execute('ALTER TABLE sometable AND COLUMN gener TEXT')
# conn.commit()
#
# c.execute('INSERT INTO sometable VALUES (?, ?, ?)', ('Jane Doe', 34, 'female'))
# conn.commit()
#
# c.execute('SELECT name, age FROM sometable WHERE name=?', ('Jonh Doe',))
# row = list(c)[0]
# john = dict(name=row[0], age=row[1])

# %% [markdown]
# #### SQLite 데이터베이스와 연결시도
# db = dataset.connect("sqlite:///mydatabase.db")
#
# #### MySQL 데이터베이스와 연결시도
# db = dataset.connect("mysql://user:password@localhost/mydatabase")
#
# #### PostgreSQL 데이터베이스와 연결시도
# db = dataset.connect('postgresql://scott:tiger@localhost:5432/mydatabase')

# %% [markdown]
# ### Melon chart DB 저장하기

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

request_headers = {
    'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_13_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/77.0.3865.90 Safari/537.36',
    'Referer': 'http://www.melon.com'
}
url = "https://www.melon.com/chart/index.htm"
res = requests.get(url, headers=request_headers)
html = res.text

tag_list = soup.select(".d_song_list tr")
del tag_list[0]  # 첫번째 곡은 100위 곡이 아니기 때문에 삭제
song_list = []
for tag in tag_list:
    song = {
        "title" : tag.select_one("a[href*=playSong]").text,
        "rank" : tag.select_one(".rank").text,
        "singer": tag.select_one("a[href*=goArtistDetail]").text,
        "album": tag.select("a[href*=goAlbumDetail]")[1].text,
    }
    song_list.append(song)
    
df = pd.DataFrame(song_list)
df.tail()
# Out:
#             title rank     singer                                album
# 95      사계 (하루살이)   96      엠씨더맥스                             Circular
# 96      Love Shot   97        EXO  LOVE SHOT - The 5th Album Repackage
# 97             XX   98     볼빨간사춘기                             Two Five
# 98  Way Back Home   99  숀 (SHAUN)                                 Take
# 99        우리 만난다면  100        스무살                                 낮과 밤

# %%
import dataset

# %%
db = dataset.connect('sqlite:///melon.db')
table = db['chart']
table.insert?

# %%
for song in song_list:
    table.insert(song)

# %%
for row in table.all():
    print(row)
# Out:
# OrderedDict([('id', 1), ('title', '어떻게 이별까지 사랑하겠어, 널 사랑하는 거지'), ('rank', '1'), ('singer', 'AKMU (악동뮤지션)'), ('album', '항해')])
# OrderedDict([('id', 2), ('title', '새 사랑'), ('rank', '2'), ('singer', '송하예'), ('album', '새 사랑')])
# OrderedDict([('id', 3), ('title', '흔들리는 꽃들 속에서 네 샴푸향이 느껴진거야'), ('rank', '3'), ('singer', '장범준'), ('album', '멜로가 체질 OST Part 3')])
# OrderedDict([('id', 4), ('title', '떨어지는 낙엽까지도'), ('rank', '4'), ('singer', '헤이즈 (Heize)'), ('album', '만추')])
# OrderedDict([('id', 5), ('title', '있어줘요'), ('rank', '5'), ('singer', '장덕철'), ('album', '있어줘요')])
# OrderedDict([('id', 6), ('title', '조금 취했어 (Prod. 2soo)'), ('rank', '6'), ('singer', '임재현'), ('album', '조금 취했어')])
# OrderedDict([('id', 7), ('title', '허전해'), ('rank', '7'), ('singer', '폴킴'), ('album', "정규 2집 '마음, 하나'")])
# OrderedDict([('id', 8), ('title', '사랑이란 멜로는 없어'), ('rank', '8'), ('singer', '전상근'), ('album', '사랑이란 멜로는 없어')])
# OrderedDict([('id', 9), ('title', '워커홀릭'), ('rank', '9'), ('singer', '볼빨간사춘기'), ('album', 'Two Five')])
# OrderedDict([('id', 10), ('title', '안녕'), ('rank', '10'), ('singer', '폴킴'), ('album', '호텔 델루나 OST Part.10')])
# OrderedDict([('id', 11), ('title', '오늘도 빛나는 너에게 (To You My Light) (Feat.이라온)'), ('rank', '11'), ('singer', '마크툽 (MAKTUB)'), ('album', 'Red Moon : To You My Light')])
# OrderedDict([('id', 12), ('title', '시든 꽃에 물을 주듯'), ('rank', '12'), ('singer', 'HYNN(박혜원)'), ('album', '시든 꽃에 물을 주듯')])
# OrderedDict([('id', 13), ('title', '가을밤 떠난 너'), ('rank', '13'), ('singer', '케이시 (Kassy)'), ('album', 'Rewind')])
# OrderedDict([('id', 14), ('title', 'Feel Special'), ('rank', '14'), ('singer', 'TWICE (트와이스)'), ('album', 'Feel Special')])
# OrderedDict([('id', 15), ('title', '니 소식'), ('rank', '15'), ('singer', '송하예'), ('album', '니 소식')])
# OrderedDict([('id', 16), ('title', '우리 어떻게 할까요'), ('rank', '16'), ('singer', '첸 (CHEN)'), ('album', '사랑하는 그대에게 - The 2nd Mini Album')])
# OrderedDict([('id', 17), ('title', '기억해줘요 내 모든 날과 그때를'), ('rank', '17'), ('singer', '거미'), ('album', '호텔 델루나 OST Part.7')])
# OrderedDict([('id', 18), ('title', '포장마차'), ('rank', '18'), ('singer', '황인욱'), ('album', '포장마차')])
# OrderedDict([('id', 19), ('title', '만추 (Feat. Crush)'), ('rank', '19'), ('singer', '헤이즈 (Heize)'), ('album', '만추')])
# OrderedDict([('id', 20), ('title', '가끔 이러다'), ('rank', '20'), ('singer', '펀치 (Punch)'), ('album', '가끔 이러다')])
# OrderedDict([('id', 21), ('title', '헤어지자 (Prod. 정키)'), ('rank', '21'), ('singer', '휘인 (Whee In)'), ('album', 'soar')])
# OrderedDict([('id', 22), ('title', '2002'), ('rank', '22'), ('singer', 'Anne-Marie'), ('album', 'Speak Your Mind (Deluxe)')])
# OrderedDict([('id', 23), ('title', 'Señorita'), ('rank', '23'), ('singer', 'Shawn Mendes'), ('album', 'Señorita')])
# OrderedDict([('id', 24), ('title', '천둥벌거숭이 (Feat. Jvcki Wai, 염따)'), ('rank', '24'), ('singer', '지코 (ZICO)'), ('album', 'THINKING Part.1')])
# OrderedDict([('id', 25), ('title', '사랑에 연습이 있었다면 (Prod. 2soo)'), ('rank', '25'), ('singer', '임재현'), ('album', '사랑에 연습이 있었다면')])
# OrderedDict([('id', 26), ('title', '그대라는 시'), ('rank', '26'), ('singer', '태연 (TAEYEON)'), ('album', '호텔 델루나 OST Part.3')])
# OrderedDict([('id', 27), ('title', '술이 문제야'), ('rank', '27'), ('singer', '장혜진'), ('album', '술이 문제야')])
# OrderedDict([('id', 28), ('title', '사랑이 식었다고 말해도 돼'), ('rank', '28'), ('singer', '먼데이 키즈 (Monday Kiz)'), ('album', '사랑이 식었다고 말해도 돼')])
# OrderedDict([('id', 29), ('title', '작은 것들을 위한 시 (Boy With Luv) feat. Halsey'), ('rank', '29'), ('singer', '방탄소년단'), ('album', 'MAP OF THE SOUL : PERSONA')])
# OrderedDict([('id', 30), ('title', '모든 날, 모든 순간 (Every day, Every Moment)'), ('rank', '30'), ('singer', '폴킴'), ('album', '`키스 먼저 할까요?` OST Part.3')])
# OrderedDict([('id', 31), ('title', 'bad guy'), ('rank', '31'), ('singer', 'Billie Eilish'), ('album', 'WHEN WE ALL FALL ASLEEP, WHERE DO WE GO?')])
# OrderedDict([('id', 32), ('title', '호랑이소굴 (Feat. Jvcki Wai)'), ('rank', '32'), ('singer', '기리보이'), ('album', '호랑이소굴')])
# OrderedDict([('id', 33), ('title', '사람'), ('rank', '33'), ('singer', '지코 (ZICO)'), ('album', 'THINKING Part.1')])
# OrderedDict([('id', 34), ('title', '이별행동'), ('rank', '34'), ('singer', '이우'), ('album', '이별행동')])
# OrderedDict([('id', 35), ('title', '다시 만날까 봐'), ('rank', '35'), ('singer', 'V.O.S'), ('album', '다시 만날까 봐')])
# OrderedDict([('id', 36), ('title', 'BAND'), ('rank', '36'), ('singer', '창모 (CHANGMO)'), ('album', 'BAND')])
# OrderedDict([('id', 37), ('title', '헤어져줘서 고마워'), ('rank', '37'), ('singer', '벤'), ('album', '헤어져줘서 고마워')])
# OrderedDict([('id', 38), ('title', '복숭아'), ('rank', '38'), ('singer', '아이유'), ('album', '스무 살의 봄')])
# OrderedDict([('id', 39), ('title', '나의 어깨에 기대어요'), ('rank', '39'), ('singer', '10cm'), ('album', '호텔 델루나 OST Part.2')])
# OrderedDict([('id', 40), ('title', 'Done For Me'), ('rank', '40'), ('singer', '펀치 (Punch)'), ('album', '호텔 델루나 OST Part.12')])
# OrderedDict([('id', 41), ('title', '내 목소리 들리니'), ('rank', '41'), ('singer', '벤'), ('album', '호텔 델루나 OST Part.9')])
# OrderedDict([('id', 42), ('title', '꽃처럼 예쁜 그대'), ('rank', '42'), ('singer', '임한별'), ('album', '동백꽃 필 무렵 (KBS2 수목드라마) OST - Part.4')])
# OrderedDict([('id', 43), ('title', '달'), ('rank', '43'), ('singer', 'AKMU (악동뮤지션)'), ('album', '항해')])
# OrderedDict([('id', 44), ('title', '벗'), ('rank', '44'), ('singer', '닐로(Nilo)'), ('album', '벗')])
# OrderedDict([('id', 45), ('title', 'Speechless (Full)'), ('rank', '45'), ('singer', 'Naomi Scott'), ('album', 'Aladdin (Original Motion Picture Soundtrack)')])
# OrderedDict([('id', 46), ('title', '사월이 지나면 우리 헤어져요 (Beautiful goodbye)'), ('rank', '46'), ('singer', '첸 (CHEN)'), ('album', '사월, 그리고 꽃 - The 1st Mini Album')])
# OrderedDict([('id', 47), ('title', '널 안지 않을 수 있어야지'), ('rank', '47'), ('singer', '첸 (CHEN)'), ('album', '사랑하는 그대에게 - The 2nd Mini Album')])
# OrderedDict([('id', 48), ('title', '너를 만나'), ('rank', '48'), ('singer', '폴킴'), ('album', '너를 만나')])
# OrderedDict([('id', 49), ('title', '사계 (Four Seasons)'), ('rank', '49'), ('singer', '태연 (TAEYEON)'), ('album', '사계 (Four Seasons)')])
# OrderedDict([('id', 50), ('title', '내 맘을 볼 수 있나요'), ('rank', '50'), ('singer', '헤이즈 (Heize)'), ('album', '호텔 델루나 OST Part.5')])
# OrderedDict([('id', 51), ('title', '날라리 (LALALAY)'), ('rank', '51'), ('singer', '선미'), ('album', '날라리 (LALALAY)')])
# OrderedDict([('id', 52), ('title', '우리 시작해도 괜찮을까요'), ('rank', '52'), ('singer', '정준일'), ('album', '우리 시작해도 괜찮을까요')])
# OrderedDict([('id', 53), ('title', '헤어질 자신 있니 (Narr. SBS 박선영 아나운서)'), ('rank', '53'), ('singer', '앤씨아'), ('album', '헤어질 자신 있니')])
# OrderedDict([('id', 54), ('title', '솔직하게 말해서 나'), ('rank', '54'), ('singer', '김나영'), ('album', '솔직하게 말해서 나')])
# OrderedDict([('id', 55), ('title', '너에게 못했던 내 마지막 말은'), ('rank', '55'), ('singer', '다비치'), ('album', '너에게 못했던 내 마지막 말은')])
# OrderedDict([('id', 56), ('title', '그때가 좋았어'), ('rank', '56'), ('singer', '케이시 (Kassy)'), ('album', '그때가 좋았어')])
# OrderedDict([('id', 57), ('title', 'Paris In The Rain'), ('rank', '57'), ('singer', 'Lauv'), ('album', 'I met you when I was 18. (the playlist)')])
# OrderedDict([('id', 58), ('title', '노래방에서'), ('rank', '58'), ('singer', '장범준'), ('album', '장범준 3집')])
# OrderedDict([('id', 59), ('title', '내 안부'), ('rank', '59'), ('singer', '이우'), ('album', '내 안부')])
# OrderedDict([('id', 60), ('title', '나빠(NAPPA)'), ('rank', '60'), ('singer', 'Crush'), ('album', '나빠(NAPPA)')])
# OrderedDict([('id', 61), ('title', 'ICY'), ('rank', '61'), ('singer', 'ITZY (있지)'), ('album', 'IT`z ICY')])
# OrderedDict([('id', 62), ('title', '전화를 할까봐'), ('rank', '62'), ('singer', '오반'), ('album', '전화를 할까봐')])
# OrderedDict([('id', 63), ('title', '일기'), ('rank', '63'), ('singer', '헤이즈 (Heize)'), ('album', '만추')])
# OrderedDict([('id', 64), ('title', 'FANCY'), ('rank', '64'), ('singer', 'TWICE (트와이스)'), ('album', 'FANCY YOU')])
# OrderedDict([('id', 65), ('title', 'FREEDOM'), ('rank', '65'), ('singer', 'AKMU (악동뮤지션)'), ('album', '항해')])
# OrderedDict([('id', 66), ('title', 'FLASH'), ('rank', '66'), ('singer', 'X1 (엑스원)'), ('album', '비상 : QUANTUM LEAP')])
# OrderedDict([('id', 67), ('title', '인사'), ('rank', '67'), ('singer', '멜로망스'), ('album', '인사')])
# OrderedDict([('id', 68), ('title', '가을속에서'), ('rank', '68'), ('singer', '화사(Hwa Sa)'), ('album', '화실(化-室:atelier)')])
# OrderedDict([('id', 69), ('title', '주저하는 연인들을 위해'), ('rank', '69'), ('singer', '잔나비'), ('album', '전설')])
# OrderedDict([('id', 70), ('title', '꿈속에 너 (Feat. 전상근)'), ('rank', '70'), ('singer', '에이치코드 (H:CODE)'), ('album', '두 번째 이야기')])
# OrderedDict([('id', 71), ('title', 'Snapping'), ('rank', '71'), ('singer', '청하'), ('album', 'Flourishing')])
# OrderedDict([('id', 72), ('title', '봄날'), ('rank', '72'), ('singer', '방탄소년단'), ('album', 'YOU NEVER WALK ALONE')])
# OrderedDict([('id', 73), ('title', '그대에게'), ('rank', '73'), ('singer', '첸 (CHEN)'), ('album', '사랑하는 그대에게 - The 2nd Mini Album')])
# OrderedDict([('id', 74), ('title', '괜찮아도 괜찮아 (That`s okay)'), ('rank', '74'), ('singer', '디오 (D.O.)'), ('album', '괜찮아도 괜찮아 (That`s okay) - SM STATION')])
# OrderedDict([('id', 75), ('title', '가라사대'), ('rank', '75'), ('singer', 'BewhY (비와이)'), ('album', 'The Movie Star')])
# OrderedDict([('id', 76), ('title', 'Believer'), ('rank', '76'), ('singer', 'Imagine Dragons'), ('album', 'Evolve')])
# OrderedDict([('id', 77), ('title', '물 만난 물고기'), ('rank', '77'), ('singer', 'AKMU (악동뮤지션)'), ('album', '항해')])
# OrderedDict([('id', 78), ('title', '고운 그대는 시들지 않으리'), ('rank', '78'), ('singer', '첸 (CHEN)'), ('album', '사랑하는 그대에게 - The 2nd Mini Album')])
# OrderedDict([('id', 79), ('title', '담아 (Feat. 염따, pH-1) (Prod. BOYCOLD)'), ('rank', '79'), ('singer', '스윙스'), ('album', '쇼미더머니 8 Episode 1')])
# OrderedDict([('id', 80), ('title', 'Another Day'), ('rank', '80'), ('singer', '먼데이 키즈 (Monday Kiz)'), ('album', '호텔 델루나 OST Part.1')])
# OrderedDict([('id', 81), ('title', '그댄 모르죠'), ('rank', '81'), ('singer', '첸 (CHEN)'), ('album', '사랑하는 그대에게 - The 2nd Mini Album')])
# OrderedDict([('id', 82), ('title', 'IDOL'), ('rank', '82'), ('singer', '방탄소년단'), ('album', 'LOVE YOURSELF 結 `Answer`')])
# OrderedDict([('id', 83), ('title', '사랑 둘'), ('rank', '83'), ('singer', '김필'), ('album', '사랑 둘')])
# OrderedDict([('id', 84), ('title', '밤 끝없는 밤'), ('rank', '84'), ('singer', 'AKMU (악동뮤지션)'), ('album', '항해')])
# OrderedDict([('id', 85), ('title', '아퍼 (Feat. Kid Milli, Lil tachi, 김승민, NO:EL, C JAMM)'), ('rank', '85'), ('singer', '기리보이'), ('album', '100년제전문대학')])
# OrderedDict([('id', 86), ('title', '굿밤 (GOOD BAM)'), ('rank', '86'), ('singer', '엔플라잉 (N.Flying)'), ('album', '야호(夜好)')])
# OrderedDict([('id', 87), ('title', '나만 아픈 일'), ('rank', '87'), ('singer', '이해리 (다비치)'), ('album', '나만 아픈 일')])
# OrderedDict([('id', 88), ('title', '비'), ('rank', '88'), ('singer', '폴킴'), ('album', '비')])
# OrderedDict([('id', 89), ('title', '뱃노래'), ('rank', '89'), ('singer', 'AKMU (악동뮤지션)'), ('album', '항해')])
# OrderedDict([('id', 90), ('title', 'DAUM (Feat. Colde)'), ('rank', '90'), ('singer', '헤이즈 (Heize)'), ('album', '만추')])
# OrderedDict([('id', 91), ('title', 'We don`t talk together (Feat. 기리보이) (Prod. SUGA)'), ('rank', '91'), ('singer', '헤이즈 (Heize)'), ('album', 'We don`t talk together')])
# OrderedDict([('id', 92), ('title', '달라달라'), ('rank', '92'), ('singer', 'ITZY (있지)'), ('album', 'IT`z Different')])
# OrderedDict([('id', 93), ('title', '잘 자요'), ('rank', '93'), ('singer', '첸 (CHEN)'), ('album', '사랑하는 그대에게 - The 2nd Mini Album')])
# OrderedDict([('id', 94), ('title', 'Goodbye'), ('rank', '94'), ('singer', '박효신'), ('album', 'Goodbye')])
# OrderedDict([('id', 95), ('title', '음파음파 (Umpah Umpah)'), ('rank', '95'), ('singer', 'Red Velvet (레드벨벳)'), ('album', '‘The ReVe Festival’ Day 2')])
# OrderedDict([('id', 96), ('title', '사계 (하루살이)'), ('rank', '96'), ('singer', '엠씨더맥스'), ('album', 'Circular')])
# OrderedDict([('id', 97), ('title', 'Love Shot'), ('rank', '97'), ('singer', 'EXO'), ('album', 'LOVE SHOT - The 5th Album Repackage')])
# OrderedDict([('id', 98), ('title', 'XX'), ('rank', '98'), ('singer', '볼빨간사춘기'), ('album', 'Two Five')])
# OrderedDict([('id', 99), ('title', 'Way Back Home'), ('rank', '99'), ('singer', '숀 (SHAUN)'), ('album', 'Take')])
# OrderedDict([('id', 100), ('title', '우리 만난다면'), ('rank', '100'), ('singer', '스무살'), ('album', '낮과 밤')])

# %%
# db 삭제
# !rm ex1.db, ex2.db, example1.db
# Out:
# rm: ex1.db,: No such file or directory
# rm: ex2.db,: No such file or directory

# %%
table.count()
# Out:
# 100

# %% [markdown]
# ### jsonl로 먼저 정리한 후에 모아서 RDB로 보내기
#
# * 크롤링 후에 저장해야 할 양이 방대할 때, 바로 RDB로 저장하기 보다 로컬 파일(jsonl 등)에 저장한 후에 모아서 RDB(로컬 or 외부)로 보낼 수 있다.

# %%
# 크롤링한 결과를 지정파일에 계속 누적

def get_melon_chart():
    request_headers = {
    'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_13_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/77.0.3865.90 Safari/537.36',
    'Referer': 'http://www.melon.com'}
    url = "https://www.melon.com/chart/index.htm"
    res = requests.get(url, headers=request_headers)
    html = res.text

    tag_list = soup.select(".d_song_list tr")
    del tag_list[0]  # 첫번째 곡은 100위 곡이 아니기 때문에 삭제
    song_list = []
    for tag in tag_list:
        song = {
            "title" : tag.select_one("a[href*=playSong]").text,
            "rank" : tag.select_one(".rank").text,
            "singer": tag.select_one("a[href*=goArtistDetail]").text,
            "album": tag.select("a[href*=goAlbumDetail]")[1].text,}
        song_list.append(song)
    return song_list

# 1. json 파일에 저장
import json
with open("melon_chart_20191017.jl", "at", encoding='utf8') as f:
    for song in get_melon_chart():
        json_string = json.dumps(song, ensure_ascii=False)
        f.write(json_string + '\n')

# %%
# 2. MySQL, PostgreSQL 데이터베이스로 INSERT
db = dataset.connect("sqlite:///melon.db")

# 일정 주기단위로 모아서 한번에 DB에 저장
with open("melon_chart_20191017.jl", 'rt', encoding="utf8") as f:
    # 지정 파일내 모든 내역을 한번에 리스트화(실행시간/메모리 이슈 등)
    song_list = [json.loads(line) for line in f if line]  # if line 빈줄 인지 아닌지 확인, 빈줄은 무시하겠다.
    table = db['chart']
    table.insert_many(song_list, chunk_size=1000)  # default 1000

# %%
table.count()
# Out:
# 200

# %% [markdown]
# ### 개선 : 조금씩 읽어가면서 DB에 저장하기

# %%
def chunk_list(iterable, chunk_size):
    chunk = []
    for el in iterable:
        chunk.append(el)
        if len(chunk) == chunk_size:
            yield chunk
            chunk = []
    if chunk:
        yield chunk

# %%
# 일정 주기 단위로 모아서 한번에 DB에 저장

with open("melon_chart_20191017.jl", "rt", encoding="utf8") as f:
    table = db["chart"]
    
    for line_list in chunk_list(f, 1000):
        song_list = [json.loads(line) for line in line_list]
        table.insert_many(song_list, chunk_size=1000)  # 1000개 단위로 읽으면서 수행됨

# %%
table.count()
# Out:
# 300

# %% [markdown]
# ## 각 클라우드 벤더 서비스 활용 가능
# 벤더별 NoSQL 데이터베이스와 정적 스토리지
# * AWS : DynamoDB, Simple Storage Service(S3) <- AWS Lambda
# * Microsoft Azure : Azure Table, Azure Storage <- Azure Function
# * Google Cloud : Datastore, Cloud Storage <- Google Cloud Function
